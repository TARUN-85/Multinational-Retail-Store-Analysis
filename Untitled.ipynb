# %% [markdown]
# # <font color=red>Import all the relevant library</font>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import math
from scipy.stats import norm

# %% [markdown]
# # <font color=red>Defining Problem Statements</font>

# %% [markdown]
# > 1.) The Management wants to know the customer Purchase Behaviour on the basis of Purchase Amount, Customer Gender's & Other Factors

# %% [markdown]
# > 2.) Also getting an idea about which gender buy more frequentl on Good Friday. To increase the Sales

# %% [markdown]
# > 3.) Knowing the factors affecting the purchase of products to increase Sales & Profit

# %% [markdown]
# # <font color=red>Importing Data set</font>

# %%
df = pd.read_csv('walmart_data.txt')
df
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17          10             A
# 1       1000001  P00248942      F   0-17          10             A
# 2       1000001  P00087842      F   0-17          10             A
# 3       1000001  P00085442      F   0-17          10             A
# 4       1000002  P00285442      M    55+          16             C
# ...         ...        ...    ...    ...         ...           ...
# 550063  1006033  P00372445      M  51-55          13             B
# 550064  1006035  P00375436      F  26-35           1             C
# 550065  1006036  P00375436      F  26-35          15             B
# 550066  1006038  P00375436      F    55+           1             C
# 550067  1006039  P00371644      F  46-50           0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category  Purchase
# 0                               2               0                 3      8370
# ...

# %% [markdown]
# # <font color=red>1.Analyzing Basic Metrix</font>

# %% [markdown]
# #### 1.1. Shape of Data

# %%
df.shape
# Out:
# (550068, 10)

# %% [markdown]
# #### 1.2. Information about data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550068 entries, 0 to 550067
# Data columns (total 10 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     550068 non-null  int64
#  1   Product_ID                  550068 non-null  object
#  2   Gender                      550068 non-null  object
#  3   Age                         550068 non-null  object
#  4   Occupation                  550068 non-null  int64
#  5   City_Category               550068 non-null  object
#  6   Stay_In_Current_City_Years  550068 non-null  object
#  7   Marital_Status              550068 non-null  int64
#  8   Product_Category            550068 non-null  int64
#  9   Purchase                    550068 non-null  int64
# dtypes: int64(5), object(5)
# memory usage: 42.0+ MB

# %% [markdown]
# #### 1.3. Data types of columns

# %%
df.dtypes
# Out:
# User_ID                        int64
# Product_ID                    object
# Gender                        object
# Age                           object
# Occupation                     int64
# City_Category                 object
# Stay_In_Current_City_Years    object
# Marital_Status                 int64
# Product_Category               int64
# Purchase                       int64
# dtype: object

# %% [markdown]
# #### 1.4. Conversion to categorical variable

# %%
# Convert Gender to categorical variable
df['Gender'] = df['Gender'].astype('category')

# Convert Marital_status to categorical variable
df['Marital_Status'] = df['Marital_Status'].astype('category')

#Convert City_category to Category
df['City_Category'] = df['City_Category'].astype('category')

# %% [markdown]
# #### 1.5. Missing values or Null values Detection

# %%
df.isna().sum()
# Out:
# User_ID                       0
# Product_ID                    0
# Gender                        0
# Age                           0
# Occupation                    0
# City_Category                 0
# Stay_In_Current_City_Years    0
# Marital_Status                0
# Product_Category              0
# Purchase                      0
# dtype: int64

# %% [markdown]
# #### 1.6. Statistical summary

# %%
df.describe(include = 'all')
# Out:
#              User_ID Product_ID  Gender     Age     Occupation City_Category  \
# count   5.500680e+05     550068  550068  550068  550068.000000        550068
# unique           NaN       3631       2       7            NaN             3
# top              NaN  P00265242       M   26-35            NaN             B
# freq             NaN       1880  414259  219587            NaN        231173
# mean    1.003029e+06        NaN     NaN     NaN       8.076707           NaN
# std     1.727592e+03        NaN     NaN     NaN       6.522660           NaN
# min     1.000001e+06        NaN     NaN     NaN       0.000000           NaN
# 25%     1.001516e+06        NaN     NaN     NaN       2.000000           NaN
# 50%     1.003077e+06        NaN     NaN     NaN       7.000000           NaN
# 75%     1.004478e+06        NaN     NaN     NaN      14.000000           NaN
# max     1.006040e+06        NaN     NaN     NaN      20.000000           NaN
#
# ...

# %% [markdown]
# # <font color=red>2. Non- Graphical Analysis</font>

# %% [markdown]
# #### 2.1. Values counts

# %%
#Checking for gender wise calculation
df['Gender'].value_counts()
# Out:
# M    414259
# F    135809
# Name: Gender, dtype: int64

# %%
# Checking for No of City
df['City_Category'].value_counts()
# Out:
# B    231173
# C    171175
# A    147720
# Name: City_Category, dtype: int64

# %%
# Checking for Married & Not Married People
df['Marital_Status'].value_counts()

# 0:Unmarried  , 1:Married
# Out:
# 0    324731
# 1    225337
# Name: Marital_Status, dtype: int64

# %%
# Checking for No of people in a particular Age group 
df['Age'].value_counts()
# Out:
# 26-35    219587
# 36-45    110013
# 18-25     99660
# 46-50     45701
# 51-55     38501
# 55+       21504
# 0-17      15102
# Name: Age, dtype: int64

# %%
# Checking for 'Stay_In_Current_City_Years'
df['Stay_In_Current_City_Years'].value_counts()
# Out:
# 1     193821
# 2     101838
# 3      95285
# 4+     84726
# 0      74398
# Name: Stay_In_Current_City_Years, dtype: int64

# %% [markdown]
# #### 2.2. Unique Values

# %%
# No of Unique User_ID & distinct unique User_ID registered
print('No of Unique User_ID :',df['User_ID'].nunique())

df['User_ID'].unique()
# Out:
# No of Unique User_ID : 5891
# array([1000001, 1000002, 1000003, ..., 1004113, 1005391, 1001529],
#       dtype=int64)

# %%
# No of Unique Product_ID & distinct unique Product_ID registered
print('No of Unique Product_ID :',df['Product_ID'].nunique())

df['Product_ID'].unique()
# Out:
# No of Unique Product_ID : 3631
# array(['P00069042', 'P00248942', 'P00087842', ..., 'P00370293',
#        'P00371644', 'P00370853'], dtype=object)

# %%
# No of Unique Product Category 
print('No of Unique Product_Category :',df['Product_Category'].nunique())

df['Product_Category'].unique()
# Out:
# No of Unique Product_Category : 20
# array([ 3,  1, 12,  8,  5,  4,  2,  6, 14, 11, 13, 15,  7, 16, 18, 10, 17,
#         9, 20, 19], dtype=int64)

# %% [markdown]
# # <font color=red>3. Graphical Analysis</font>

# %% [markdown]
# #### 3.1. Univariate Analysis

# %%
plt.figure(figsize=(15,15))
plt.subplot(2,2,1)
sns.countplot(data=df,x='Gender',order=df['Gender'].value_counts(ascending=False).index)
plt.title('Gender vise no of Orders')

plt.subplot(2,2,2)
sns.countplot(data=df,x='Age',order=df['Age'].value_counts(ascending=False).index)
plt.title('Age vise no of Orders')
plt.xticks(rotation=45)

plt.subplot(2,2,3)
sns.countplot(data=df,x='Marital_Status',order=df['Marital_Status'].value_counts(ascending=False).index)
plt.title('Marital_Status vise no of Orders')

plt.subplot(2,2,4)
sns.countplot(data=df,x='City_Category',order=df['City_Category'].value_counts(ascending=False).index)
plt.title('City_Category vise no of Orders')
plt.xticks(rotation=45)
plt.show()

plt.figure(figsize=(15,3))
plt.title('No of Years in Current City counts')
sns.countplot(data=df,y='Stay_In_Current_City_Years',order=df['Stay_In_Current_City_Years'].value_counts(ascending=False).index)
plt.show()

# %% [markdown]
# #### 3.2 Bivariate Analysis

# %%
# Before removing outliers values
print("Before removing outliers values")
plt.figure(figsize=(20,5))
plt.title('Product Category Purchased by customer Gender wise at different costs')
sns.boxplot(data=df,x='Product_Category',y='Purchase',hue='Gender')
plt.show()


# After removing outliers values
print("After removing outliers values")
a = df[['Product_Category','Purchase','Gender']].copy()
for i in range(1,21):
    #Removing Male outliers
    b = a.loc[(a['Product_Category']==i) & (a['Gender']=='M'),'Purchase']
    p_25,p_75 = b.quantile([0.25,0.75])
    iqr = p_75 - p_25
    mx = p_75 + iqr*1.5
    mn = p_25 - iqr*1.5
    a.drop(index=a[ ((a['Gender']=='M') & a['Product_Category']==i) & ((a['Purchase']> mx) | (a['Purchase'] < mn))]
           .index,inplace=True)
    
    #Removing Female outliers
    c = a.loc[(a['Product_Category']==i) & (a['Gender']=='F'),'Purchase']
    p_25,p_75 = c.quantile([0.25,0.75])
    iqr = p_75 - p_25
    mx = p_75 + iqr*1.5
    mn = p_25 - iqr*1.5
    a.drop(index=a[ ((a['Gender']=='F') & a['Product_Category']==i) & ((a['Purchase']> mx) | (a['Purchase'] < mn))].index,inplace=True)


plt.figure(figsize=(20,5))
sns.boxplot(data=a,x='Product_Category',y='Purchase',hue='Gender')
plt.show()
# Out:
# Before removing outliers values
# After removing outliers values

# %% [markdown]
# #### 3.3. Correlation Analysis

# %% [markdown]
# > **Heatmap**

# %%
plt.figure(figsize=(25,10))
plt.subplot(2,2,1)
plt.title("Product category VS Gender wise distribution of Total Purchase |",loc='left', )
a = (df[['Gender','Product_Category','Purchase']].groupby(['Gender','Product_Category']).aggregate('sum').reset_index()
     .pivot(index='Product_Category',columns='Gender',values='Purchase'))
sns.heatmap(a,annot=True,fmt='d')

plt.subplot(2,2,2)
plt.title("|  Occupation Vs Gender wise distribution of unique City_Category",loc='left', )
b = (df.groupby(['Gender','Occupation']).aggregate({'City_Category': lambda x: x.nunique()}).reset_index()
     .pivot(index='Occupation',columns='Gender',values='City_Category'))
sns.heatmap(b,annot=True,fmt='d')

plt.subplot(2,2,3)
plt.title("Age category Vs Gender wise distribution with no of distinct User_ID |",loc='left', )
c = (df.groupby(['Gender','Age']).aggregate({'User_ID': lambda x: x.nunique()}).reset_index()
     .pivot(index='Age',columns='Gender',values='User_ID'))
sns.heatmap(c,annot=True,fmt='d')

plt.subplot(2,2,4)
plt.title("Age category Vs Gender wise distribution with no of distinct Product_ID |",loc='left', )
c = (df.groupby(['Gender','Age'])['Product_ID'].aggregate('count')
     .reset_index().pivot(index='Age',columns='Gender',values='Product_ID'))
sns.heatmap(c,annot=True,fmt='d')


plt.show()

plt.figure(figsize=(25,5))
sns.heatmap(data=df.corr(),annot=True)
plt.show()
# Out:
# C:\Users\ragha\AppData\Local\Temp\ipykernel_13936\1138530690.py:30: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data=df.corr(),annot=True)

# %% [markdown]
# # <font color=red>4.Missing Value & Outlier Detection</font>

# %% [markdown]
# #### 4.1 Missing value detection

# %%
df.isna().sum()
# Out:
# User_ID                       0
# Product_ID                    0
# Gender                        0
# Age                           0
# Occupation                    0
# City_Category                 0
# Stay_In_Current_City_Years    0
# Marital_Status                0
# Product_Category              0
# Purchase                      0
# dtype: int64

# %% [markdown]
# - **There is no missing value in the above data set**

# %% [markdown]
# #### 4.2 Outliers Detection

# %% [markdown]
# > The black heavy dot are the outliers in the Dataset

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # <font color=red>5. Confidence Interval & Central limit Theorem</font>

# %% [markdown]
# ##  5.1 for Gender & Purchase

# %% [markdown]
# ### Calculation of population mean(mu) & Standard-Deviation (sd) for Gender & Purchase

# %%
# Male Population Calculations
a = df.loc[df['Gender']=='M','Purchase']
male_mu = a.mean()
male_sd = a.std()
print("The population Mean is mu:{} & population Standard Deviation is sd:{} when gender is Male".format(male_mu,male_sd))

# Female Population Calculations
a = df.loc[df['Gender']=='F','Purchase']
female_mu = a.mean()
female_sd = a.std()
print("The population Mean is mu:{} & population Standard Deviation is sd:{} when gender is Female".format(female_mu,female_sd))
# Out:
# The population Mean is mu:9437.526040472265 & population Standard Deviation is sd:5092.18620977797 when gender is Male
# The population Mean is mu:8734.565765155476 & population Standard Deviation is sd:4767.233289291458 when gender is Female

# %% [markdown]
# ###  Calculation for (300,3000,3000) sample size & Different confident (alpha = 1%,5%,10% respectively) combinations

# %%
print("For Sample size of 300 & 99% Confidence i.e. (alpha = 1%)")
sample_size = 300
Male_Sample_Purchase_Mean = []
Female_Sample_Purchase_Mean = []
for i in range(1,1000):
    Male_Mean = df.loc[df['Gender']=='M','Purchase'].sample(sample_size).mean()
    Male_Sample_Purchase_Mean.append(Male_Mean)
    Female_Mean = df.loc[df['Gender']=='F','Purchase'].sample(sample_size).mean()
    Female_Sample_Purchase_Mean.append(Female_Mean)
# Plotting histogram for both Male & Female for Purchases
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
sns.histplot(Male_Sample_Purchase_Mean,kde=True)
plt.title("Male vs Purchase")

plt.subplot(1,2,2)
sns.histplot(Female_Sample_Purchase_Mean,kde=True)
plt.title("Female vs Purchase")
plt.show()

############################ for sample(n=300) & 99% confidence calculation of CI ##########################################
# Male Sample mean Calculation & Standar deviation Calculation for Sample
Male_sample_300_sd = male_sd/math.sqrt(sample_size)
print("Standard Deviation for Male of 300 samples :",Male_sample_300_sd)

#Female Sample mean Calculation & Standar deviation Calculation for Sample
Female_sample_300_sd = female_sd/math.sqrt(sample_size)
print("Standard Deviation for Female of 300 samples :",Female_sample_300_sd)

############# Calculation of Z-Score & confidence Interval (CI = [mu - Z*(s.d/root(n)), mu - Z*(s.d/root(n))]) ################
alpha = 1/100
Z_300 = abs(norm.ppf(alpha))

# Range Calculation for Male Gender
print("CI range for Male at 99% confidence is [{}, {}]"
      .format(male_mu - Z_300 *Male_sample_300_sd,
              male_mu + Z_300 *Male_sample_300_sd))

# Range Calculation for Female people
print("CI range for Female at 99% confidence is [{}, {}]"
      .format(female_mu - Z_300 *Female_sample_300_sd,
              female_mu + Z_300 *Female_sample_300_sd))





print()
print("_ "*60)

##############################################################################################################################

print("For Sample size of 300 & 95% Confidence i.e. (alpha = 5%)")
sample_size = 300
Male_Sample_Purchase_Mean = []
Female_Sample_Purchase_Mean = []
for i in range(1,1000):
    Male_Mean = df.loc[df['Gender']=='M','Purchase'].sample(sample_size).mean()
    Male_Sample_Purchase_Mean.append(Male_Mean)
    Female_Mean = df.loc[df['Gender']=='F','Purchase'].sample(sample_size).mean()
    Female_Sample_Purchase_Mean.append(Female_Mean)
# Plotting histogram for both Male & Female for Purchases
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
sns.histplot(Male_Sample_Purchase_Mean,kde=True)
plt.title("Male vs Purchase")

plt.subplot(1,2,2)
sns.histplot(Female_Sample_Purchase_Mean,kde=True)
plt.title("Female vs Purchase")
plt.show()

############################ for sample(n=300) & 95% confidence calculation of CI ##########################################
# Male Sample mean Calculation & Standar deviation Calculation for Sample
Male_sample_300_sd = male_sd/math.sqrt(sample_size)
print("Standard Deviation for Male of 300 samples :",Male_sample_300_sd)

#Female Sample mean Calculation & Standar deviation Calculation for Sample
Female_sample_300_sd = female_sd/math.sqrt(sample_size)
print("Standard Deviation for Female of 300 samples :",Female_sample_300_sd)

############# Calculation of Z-Score & confidence Interval (CI = [mu - Z*(s.d/root(n)), mu - Z*(s.d/root(n))]) ################
alpha = 5/100
Z_300 = abs(norm.ppf(alpha))

# Range Calculation for Male Gender
print("CI range for Male at 95% confidence is [{}, {}]"
      .format(male_mu - Z_300 *Male_sample_300_sd,
              male_mu + Z_300 *Male_sample_300_sd))

# Range Calculation for Female people
print("CI range for Female at 95% confidence is [{}, {}]"
      .format(female_mu - Z_300 *Female_sample_300_sd,
              female_mu + Z_300 *Female_sample_300_sd))





print()
print("_ "*60)

##############################################################################################################################

print("For Sample size of 300 & 90% Confidence i.e. (alpha = 10%)")
sample_size = 300
Male_Sample_Purchase_Mean = []
Female_Sample_Purchase_Mean = []
for i in range(1,1000):
    Male_Mean = df.loc[df['Gender']=='M','Purchase'].sample(sample_size).mean()
    Male_Sample_Purchase_Mean.append(Male_Mean)
    Female_Mean = df.loc[df['Gender']=='F','Purchase'].sample(sample_size).mean()
    Female_Sample_Purchase_Mean.append(Female_Mean)
# Plotting histogram for both Male & Female for Purchases
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
sns.histplot(Male_Sample_Purchase_Mean,kde=True)
plt.title("Male vs Purchase")

plt.subplot(1,2,2)
sns.histplot(Female_Sample_Purchase_Mean,kde=True)
plt.title("Female vs Purchase")
plt.show()

############################ for sample(n=300) & 90% confidence calculation of CI ##########################################
# Male Sample mean Calculation & Standar deviation Calculation for Sample
Male_sample_300_sd = male_sd/math.sqrt(sample_size)
print("Standard Deviation for Male of 300 samples :",Male_sample_300_sd)

#Female Sample mean Calculation & Standar deviation Calculation for Sample
Female_sample_300_sd = female_sd/math.sqrt(sample_size)
print("Standard Deviation for Female of 300 samples :",Female_sample_300_sd)

############# Calculation of Z-Score & confidence Interval (CI = [mu - Z*(s.d/root(n)), mu - Z*(s.d/root(n))]) ################
alpha = 10/100
Z_300 = abs(norm.ppf(alpha))

# Range Calculation for Male Gender
print("CI range for Male at 90% confidence is [{}, {}]"
      .format(male_mu - Z_300 *Male_sample_300_sd,
              male_mu + Z_300 *Male_sample_300_sd))

# Range Calculation for Female people
print("CI range for Female at 90% confidence is [{}, {}]"
      .format(female_mu - Z_300 *Female_sample_300_sd,
              female_mu + Z_300 *Female_sample_300_sd))





print()
print("_ "*60)

##############################################################################################################################

print("For Sample size of 3000 & 99% Confidence i.e. (alpha = 1%)")
sample_size = 3000
Male_Sample_Purchase_Mean = []
Female_Sample_Purchase_Mean = []
for i in range(1,1000):
    Male_Mean = df.loc[df['Gender']=='M','Purchase'].sample(sample_size).mean()
    Male_Sample_Purchase_Mean.append(Male_Mean)
    Female_Mean = df.loc[df['Gender']=='F','Purchase'].sample(sample_size).mean()
    Female_Sample_Purchase_Mean.append(Female_Mean)
# Plotting histogram for both Male & Female for Purchases
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
sns.histplot(Male_Sample_Purchase_Mean,kde=True)
plt.title("Male vs Purchase")

plt.subplot(1,2,2)
sns.histplot(Female_Sample_Purchase_Mean,kde=True)
plt.title("Female vs Purchase")
plt.show()

############################ for sample(n=3000) & 99% confidence calculation of CI ##########################################
# Male Sample mean Calculation & Standar deviation Calculation for Sample
Male_sample_3000_sd = male_sd/math.sqrt(sample_size)
print("Standard Deviation for Male of 3000 samples :",Male_sample_3000_sd)

#Female Sample mean Calculation & Standar deviation Calculation for Sample
Female_sample_3000_sd = female_sd/math.sqrt(sample_size)
print("Standard Deviation for Female of 3000 samples :",Female_sample_3000_sd)

############# Calculation of Z-Score & confidence Interval (CI = [mu - Z*(s.d/root(n)), mu - Z*(s.d/root(n))]) ################
alpha = 1/100
Z_3000 = abs(norm.ppf(alpha))

# Range Calculation for Male Gender
print("CI range for Male at 99% confidence is [{}, {}]"
      .format(male_mu - Z_3000 *Male_sample_3000_sd,
              male_mu + Z_3000 *Male_sample_3000_sd))

# Range Calculation for FemaleFemale people
print("CI range for Female at 99% confidence is [{}, {}]"
      .format(female_mu - Z_3000 *Female_sample_3000_sd,
              female_mu + Z_3000 *Female_sample_3000_sd))





print()
print("_ "*60)

##############################################################################################################################

print("For Sample size of 3000 & 95% Confidence i.e. (alpha = 5%)")
sample_size = 3000
Male_Sample_Purchase_Mean = []
Female_Sample_Purchase_Mean = []
for i in range(1,1000):
    Male_Mean = df.loc[df['Gender']=='M','Purchase'].sample(sample_size).mean()
    Male_Sample_Purchase_Mean.append(Male_Mean)
    Female_Mean = df.loc[df['Gender']=='F','Purchase'].sample(sample_size).mean()
    Female_Sample_Purchase_Mean.append(Female_Mean)
# Plotting histogram for both Male & Female for Purchases
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
sns.histplot(Male_Sample_Purchase_Mean,kde=True)
plt.title("Male vs Purchase")

plt.subplot(1,2,2)
sns.histplot(Female_Sample_Purchase_Mean,kde=True)
plt.title("Female vs Purchase")
plt.show()

############################ for sample(n=3000) & 95% confidence calculation of CI ##########################################
# Male Sample mean Calculation & Standar deviation Calculation for Sample
Male_sample_3000_sd = male_sd/math.sqrt(sample_size)
print("Standard Deviation for Male of 3000 samples :",Male_sample_3000_sd)

#Female Sample mean Calculation & Standar deviation Calculation for Sample
Female_sample_3000_sd = female_sd/math.sqrt(sample_size)
print("Standard Deviation for Female of 3000 samples :",Female_sample_3000_sd)

############# Calculation of Z-Score & confidence Interval (CI = [mu - Z*(s.d/root(n)), mu - Z*(s.d/root(n))]) ################
alpha = 5/100
Z_3000 = abs(norm.ppf(alpha))

# Range Calculation for Male Gender
print("CI range for Male at 95% confidence is [{}, {}]"
      .format(male_mu - Z_3000 *Male_sample_3000_sd,
              male_mu + Z_3000 *Male_sample_3000_sd))

# Range Calculation for Female people
print("CI range for Female at 95% confidence is [{}, {}]"
      .format(female_mu - Z_3000 *Female_sample_3000_sd,
              female_mu + Z_3000 *Female_sample_3000_sd))





print()
print("_ "*60)

##############################################################################################################################

print("For Sample size of 3000 & 90% Confidence i.e. (alpha = 10%)")
sample_size = 3000
Male_Sample_Purchase_Mean = []
Female_Sample_Purchase_Mean = []
for i in range(1,1000):
    Male_Mean = df.loc[df['Gender']=='M','Purchase'].sample(sample_size).mean()
    Male_Sample_Purchase_Mean.append(Male_Mean)
    Female_Mean = df.loc[df['Gender']=='F','Purchase'].sample(sample_size).mean()
    Female_Sample_Purchase_Mean.append(Female_Mean)
# Plotting histogram for both Male & Female for Purchases
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
sns.histplot(Male_Sample_Purchase_Mean,kde=True)
plt.title("Male vs Purchase")

plt.subplot(1,2,2)
sns.histplot(Female_Sample_Purchase_Mean,kde=True)
plt.title("Female vs Purchase")
plt.show()

############################ for sample(n=3000) & 90% confidence calculation of CI ##########################################
# Male Sample mean Calculation & Standar deviation Calculation for Sample
Male_sample_3000_sd = male_sd/math.sqrt(sample_size)
print("Standard Deviation for Male of 3000 samples :",Male_sample_3000_sd)

#Female Sample mean Calculation & Standar deviation Calculation for Sample
Female_sample_3000_sd = female_sd/math.sqrt(sample_size)
print("Standard Deviation for Female of 3000 samples :",Female_sample_3000_sd)

############# Calculation of Z-Score & confidence Interval (CI = [mu - Z*(s.d/root(n)), mu - Z*(s.d/root(n))]) ################
alpha = 10/100
Z_3000 = abs(norm.ppf(alpha))

# Range Calculation for Male Gender
print("CI range for Male at 90% confidence is [{}, {}]"
      .format(male_mu - Z_3000 *Male_sample_3000_sd,
              male_mu + Z_3000 *Male_sample_3000_sd))

# Range Calculation for Female people
print("CI range for Female at 90% confidence is [{}, {}]"
      .format(female_mu - Z_3000 *Female_sample_3000_sd,
              female_mu + Z_3000 *Female_sample_3000_sd))





print()
print("_ "*60)

##############################################################################################################################

print("For Sample size of 30000 & 99% Confidence i.e. (alpha = 1%)")
sample_size = 30000
Male_Sample_Purchase_Mean = []
Female_Sample_Purchase_Mean = []
for i in range(1,1000):
    Male_Mean = df.loc[df['Gender']=='M','Purchase'].sample(sample_size).mean()
    Male_Sample_Purchase_Mean.append(Male_Mean)
    Female_Mean = df.loc[df['Gender']=='F','Purchase'].sample(sample_size).mean()
    Female_Sample_Purchase_Mean.append(Female_Mean)
# Plotting histogram for both Male & Female for Purchases
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
sns.histplot(Male_Sample_Purchase_Mean,kde=True)
plt.title("Male vs Purchase")

plt.subplot(1,2,2)
sns.histplot(Female_Sample_Purchase_Mean,kde=True)
plt.title("Female vs Purchase")
plt.show()

############################ for sample(n=30000) & 99% confidence calculation of CI ##########################################
# Male Sample mean Calculation & Standar deviation Calculation for Sample
Male_sample_30000_sd = male_sd/math.sqrt(sample_size)
print("Standard Deviation for Male of 30000 samples :",Male_sample_30000_sd)

#Female Sample mean Calculation & Standar deviation Calculation for Sample
Female_sample_30000_sd = female_sd/math.sqrt(sample_size)
print("Standard Deviation for Female of 30000 samples :",Female_sample_30000_sd)

############# Calculation of Z-Score & confidence Interval (CI = [mu - Z*(s.d/root(n)), mu - Z*(s.d/root(n))]) ################
alpha = 1/100
Z_30000 = abs(norm.ppf(alpha))

# Range Calculation for Male Gender
print("CI range for Male at 99% confidence is [{}, {}]"
      .format(male_mu - Z_30000 *Male_sample_30000_sd,
              male_mu + Z_30000 *Male_sample_30000_sd))

# Range Calculation for Female people
print("CI range for Female at 99% confidence is [{}, {}]"
      .format(female_mu - Z_30000 *Female_sample_30000_sd,
              female_mu + Z_30000 *Female_sample_30000_sd))





print()
print("_ "*60)

##############################################################################################################################

print("For Sample size of 30000 & 95% Confidence i.e. (alpha = 5%)")
sample_size = 30000
Male_Sample_Purchase_Mean = []
Female_Sample_Purchase_Mean = []
for i in range(1,1000):
    Male_Mean = df.loc[df['Gender']=='M','Purchase'].sample(sample_size).mean()
    Male_Sample_Purchase_Mean.append(Male_Mean)
    Female_Mean = df.loc[df['Gender']=='F','Purchase'].sample(sample_size).mean()
    Female_Sample_Purchase_Mean.append(Female_Mean)
# Plotting histogram for both Male & Female for Purchases
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
sns.histplot(Male_Sample_Purchase_Mean,kde=True)
plt.title("Male vs Purchase")

plt.subplot(1,2,2)
sns.histplot(Female_Sample_Purchase_Mean,kde=True)
plt.title("Female vs Purchase")
plt.show()

############################ for sample(n=30000) & 95% confidence calculation of CI ##########################################
# Male Sample mean Calculation & Standar deviation Calculation for Sample
Male_sample_30000_sd = male_sd/math.sqrt(sample_size)
print("Standard Deviation for Male of 30000 samples :",Male_sample_30000_sd)

#Female Sample mean Calculation & Standar deviation Calculation for Sample
Female_sample_30000_sd = female_sd/math.sqrt(sample_size)
print("Standard Deviation for Female of 30000 samples :",Female_sample_30000_sd)

############# Calculation of Z-Score & confidence Interval (CI = [mu - Z*(s.d/root(n)), mu - Z*(s.d/root(n))]) ################
alpha = 5/100
Z_30000 = abs(norm.ppf(alpha))

# Range Calculation for Male Gender
print("CI range for Male at 95% confidence is [{}, {}]"
      .format(male_mu - Z_30000 *Male_sample_30000_sd,
              male_mu + Z_30000 *Male_sample_30000_sd))

# Range Calculation for Female people
print("CI range for Female at 95% confidence is [{}, {}]"
      .format(female_mu - Z_30000 *Female_sample_30000_sd,
              female_mu + Z_30000 *Female_sample_30000_sd))





print()
print("_ "*60)

##############################################################################################################################

print("For Sample size of 30000 & 90% Confidence i.e. (alpha = 10%)")
sample_size = 30000
Male_Sample_Purchase_Mean = []
Female_Sample_Purchase_Mean = []
for i in range(1,1000):
    Male_Mean = df.loc[df['Gender']=='M','Purchase'].sample(sample_size).mean()
    Male_Sample_Purchase_Mean.append(Male_Mean)
    Female_Mean = df.loc[df['Gender']=='F','Purchase'].sample(sample_size).mean()
    Female_Sample_Purchase_Mean.append(Female_Mean)
# Plotting histogram for both Male & Female for Purchases
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
sns.histplot(Male_Sample_Purchase_Mean,kde=True)
plt.title("Male vs Purchase")

plt.subplot(1,2,2)
sns.histplot(Female_Sample_Purchase_Mean,kde=True)
plt.title("Female vs Purchase")
plt.show()

############################ for sample(n=30000) & 90% confidence calculation of CI ##########################################
# Male Sample mean Calculation & Standar deviation Calculation for Sample
Male_sample_30000_sd = male_sd/math.sqrt(sample_size)
print("Standard Deviation for Male of 30000 samples :",Male_sample_30000_sd)

#Female Sample mean Calculation & Standar deviation Calculation for Sample
Female_sample_30000_sd = female_sd/math.sqrt(sample_size)
print("Standard Deviation for Female of 30000 samples :",Female_sample_30000_sd)

############# Calculation of Z-Score & confidence Interval (CI = [mu - Z*(s.d/root(n)), mu - Z*(s.d/root(n))]) ################
alpha = 10/100
Z_30000 = abs(norm.ppf(alpha))

# Range Calculation for Male Gender
print("CI range for Male at 90% confidence is [{}, {}]"
      .format(male_mu - Z_30000 *Male_sample_30000_sd,
              male_mu + Z_30000 *Male_sample_30000_sd))

# Range Calculation for Female people
print("CI range for Female at 90% confidence is [{}, {}]"
      .format(female_mu - Z_30000 *Female_sample_30000_sd,
              female_mu + Z_30000 *Female_sample_30000_sd))





print()
print("_ "*60)

##############################################################################################################################
# Out:
# For Sample size of 300 & 99% Confidence i.e. (alpha = 1%)
# Standard Deviation for Male of 300 samples : 293.99750789790113
# Standard Deviation for Female of 300 samples : 275.2363422862168
# CI range for Male at 99% confidence is [8753.585563000677, 10121.466517943853]
# CI range for Female at 99% confidence is [8094.2702854191575, 9374.861244891794]
#
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# For Sample size of 300 & 95% Confidence i.e. (alpha = 5%)
# Standard Deviation for Male of 300 samples : 293.99750789790113
# Standard Deviation for Female of 300 samples : 275.2363422862168
# CI range for Male at 95% confidence is [8953.943173291707, 9921.108907652822]
# CI range for Female at 95% confidence is [8281.842269277135, 9187.289261033817]
#
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# ...

# %% [markdown]
# ## 5.2 for Married-Unmarried & Purchase

# %% [markdown]
# - 0: Unmarried & 1: Married

# %% [markdown]
# ### Calculation of population mean(mu) & Standard-Deviation (sd) for Marital Status & Purchase

# %%
# Married Population Mean & Standard-Deviation calculation
Married_Population_Mean = df.loc[df['Marital_Status']==0,'Purchase'].mean()
Married_Population_StandardDeviation = df.loc[df['Marital_Status']==0,'Purchase'].std()
print("Marital Status is 'Married' , Population mean (mu): {} & Population S.D : {}"
      .format(Married_Population_Mean,Married_Population_StandardDeviation))
print()
print("_ "*60)
print()

# Un-Married Population Mean & Standard-Deviation calculation
Un_Married_Population_Mean = df.loc[df['Marital_Status']==1,'Purchase'].mean()
Un_Married_Population_StandardDeviation = df.loc[df['Marital_Status']==1,'Purchase'].std()
print("Marital Status is 'Un-Married' , Population mean (mu): {} & Population S.D : {}"
      .format(Un_Married_Population_Mean,Un_Married_Population_StandardDeviation))
# Out:
# Marital Status is 'Married' , Population mean (mu): 9265.907618921507 & Population S.D : 5027.347858674449
#
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
#
# Marital Status is 'Un-Married' , Population mean (mu): 9261.174574082374 & Population S.D : 5016.897377793055

# %% [markdown]
# ##  Calculation for (300,3000,30000) Sample size & different confidence i.e. (alpha = 1, 5,10%) combinations

# %%
print("For Sample size of 300 & 99% Confidence i.e. (alpha = 1%)")
sample_size = 300
Married_Sample_Purchase_Mean = []
Un_married_Sample_Purchase_Mean = []
for i in range(1,1000):
    Married_Mean = df.loc[df['Marital_Status']==0,'Purchase'].sample(sample_size).mean()
    Married_Sample_Purchase_Mean.append(Married_Mean)
    Un_Married_Mean = df.loc[df['Marital_Status']==1,'Purchase'].sample(sample_size).mean()
    Un_married_Sample_Purchase_Mean.append(Un_Married_Mean)
# Plotting histogram for both Married & Un-Married for Purchases
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
sns.histplot(Married_Sample_Purchase_Mean,kde=True)
plt.title("Married vs Purchase")

plt.subplot(1,2,2)
sns.histplot(Un_married_Sample_Purchase_Mean,kde=True)
plt.title("Un-Married vs Purchase")
plt.show()

############################ for sample(n=300) & 99% confidence calculation of CI ##########################################
# Married Sample mean Calculation & Standar deviation Calculation for Sample
Married_sample_300_sd = Married_Population_StandardDeviation/math.sqrt(sample_size)
print("Standard Deviation for Married of 300 samples :",Married_sample_300_sd)

#Unmarried Sample mean Calculation & Standar deviation Calculation for Sample
Un_Married_sample_300_sd = Un_Married_Population_StandardDeviation/math.sqrt(sample_size)
print("Standard Deviation for Un-Marries of 300 samples :",Un_Married_sample_300_sd)

############# Calculation of Z-Score & confidence Interval (CI = [mu - Z*(s.d/root(n)), mu - Z*(s.d/root(n))]) ################
alpha = 1/100
Z_300 = abs(norm.ppf(alpha))

# Range Calculation for Married people
print("CI range for Married at 99% confidence is [{}, {}]"
      .format(Married_Population_Mean - Z_300 *Married_sample_300_sd,
              Married_Population_Mean + Z_300 *Married_sample_300_sd))

# Range Calculation for Unmarried people
print("CI range for Unmarried at 99% confidence is [{}, {}]"
      .format(Un_Married_Population_Mean - Z_300 *Un_Married_sample_300_sd,
              Un_Married_Population_Mean + Z_300 *Un_Married_sample_300_sd))





print()
print("_ "*60)

##############################################################################################################################

print("For Sample size of 300 & 95% Confidence i.e. (alpha = 5%)")
sample_size = 300
Married_Sample_Purchase_Mean = []
Un_married_Sample_Purchase_Mean = []
for i in range(1,1000):
    Married_Mean = df.loc[df['Marital_Status']==0,'Purchase'].sample(sample_size).mean()
    Married_Sample_Purchase_Mean.append(Married_Mean)
    Un_Married_Mean = df.loc[df['Marital_Status']==1,'Purchase'].sample(sample_size).mean()
    Un_married_Sample_Purchase_Mean.append(Un_Married_Mean)
# Plotting histogram for both Married & Un-Married for Purchases
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
sns.histplot(Married_Sample_Purchase_Mean,kde=True)
plt.title("Married vs Purchase")

plt.subplot(1,2,2)
sns.histplot(Un_married_Sample_Purchase_Mean,kde=True)
plt.title("Un-Married vs Purchase")
plt.show()

############################ for sample(n=300) & 95% confidence calculation of CI ##########################################
# Married Sample mean Calculation & Standar deviation Calculation for Sample
Married_sample_300_sd = Married_Population_StandardDeviation/math.sqrt(sample_size)
print("Standard Deviation for Married of 300 samples :",Married_sample_300_sd)

#Unmarried Sample mean Calculation & Standar deviation Calculation for Sample
Un_Married_sample_300_sd = Un_Married_Population_StandardDeviation/math.sqrt(sample_size)
print("Standard Deviation for Un-Marries of 300 samples :",Un_Married_sample_300_sd)

############# Calculation of Z-Score & confidence Interval (CI = [mu - Z*(s.d/root(n)), mu - Z*(s.d/root(n))]) ################
alpha = 5/100
Z_300 = abs(norm.ppf(alpha))

# Range Calculation for Married people
print("CI range for Married at 95% confidence is [{}, {}]"
      .format(Married_Population_Mean - Z_300 *Married_sample_300_sd,
              Married_Population_Mean + Z_300 *Married_sample_300_sd))

# Range Calculation for Unmarried people
print("CI range for Unmarried at 95% confidence is [{}, {}]"
      .format(Un_Married_Population_Mean - Z_300 *Un_Married_sample_300_sd,
              Un_Married_Population_Mean + Z_300 *Un_Married_sample_300_sd))





print()
print("_ "*60)

##############################################################################################################################



print("For Sample size of 300 & 90% Confidence i.e. (alpha = 10%)")
sample_size = 300
Married_Sample_Purchase_Mean = []
Un_married_Sample_Purchase_Mean = []
for i in range(1,1000):
    Married_Mean = df.loc[df['Marital_Status']==0,'Purchase'].sample(sample_size).mean()
    Married_Sample_Purchase_Mean.append(Married_Mean)
    Un_Married_Mean = df.loc[df['Marital_Status']==1,'Purchase'].sample(sample_size).mean()
    Un_married_Sample_Purchase_Mean.append(Un_Married_Mean)
# Plotting histogram for both Married & Un-Married for Purchases
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
sns.histplot(Married_Sample_Purchase_Mean,kde=True)
plt.title("Married vs Purchase")

plt.subplot(1,2,2)
sns.histplot(Un_married_Sample_Purchase_Mean,kde=True)
plt.title("Un-Married vs Purchase")
plt.show()

############################ for sample(n=300) & 90% confidence calculation of CI ##########################################
# Married Sample mean Calculation & Standar deviation Calculation for Sample
Married_sample_300_sd = Married_Population_StandardDeviation/math.sqrt(sample_size)
print("Standard Deviation for Married of 300 samples :",Married_sample_300_sd)

#Unmarried Sample mean Calculation & Standar deviation Calculation for Sample
Un_Married_sample_300_sd = Un_Married_Population_StandardDeviation/math.sqrt(sample_size)
print("Standard Deviation for Un-Marries of 300 samples :",Un_Married_sample_300_sd)

############# Calculation of Z-Score & confidence Interval (CI = [mu - Z*(s.d/root(n)), mu - Z*(s.d/root(n))]) ################
alpha = 10/100
Z_300 = abs(norm.ppf(alpha))

# Range Calculation for Married people
print("CI range for Married at 90% confidence is [{}, {}]"
      .format(Married_Population_Mean - Z_300 *Married_sample_300_sd,
              Married_Population_Mean + Z_300 *Married_sample_300_sd))

# Range Calculation for Unmarried people
print("CI range for Unmarried at 90% confidence is [{}, {}]"
      .format(Un_Married_Population_Mean - Z_300 *Un_Married_sample_300_sd,
              Un_Married_Population_Mean + Z_300 *Un_Married_sample_300_sd))





print()
print("_ "*60)

##############################################################################################################################

print("For Sample size of 3000 & 99% Confidence i.e. (alpha = 1%)")
sample_size = 3000
Married_Sample_Purchase_Mean = []
Un_married_Sample_Purchase_Mean = []
for i in range(1,1000):
    Married_Mean = df.loc[df['Marital_Status']==0,'Purchase'].sample(sample_size).mean()
    Married_Sample_Purchase_Mean.append(Married_Mean)
    Un_Married_Mean = df.loc[df['Marital_Status']==1,'Purchase'].sample(sample_size).mean()
    Un_married_Sample_Purchase_Mean.append(Un_Married_Mean)
# Plotting histogram for both Married & Un-Married for Purchases
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
sns.histplot(Married_Sample_Purchase_Mean,kde=True)
plt.title("Married vs Purchase")

plt.subplot(1,2,2)
sns.histplot(Un_married_Sample_Purchase_Mean,kde=True)
plt.title("Un-Married vs Purchase")
plt.show()

############################ for sample(n=3000) & 99% confidence calculation of CI ##########################################
# Married Sample mean Calculation & Standar deviation Calculation for Sample
Married_sample_3000_sd = Married_Population_StandardDeviation/math.sqrt(sample_size)
print("Standard Deviation for Married of 3000 samples :",Married_sample_3000_sd)

#Unmarried Sample mean Calculation & Standar deviation Calculation for Sample
Un_Married_sample_3000_sd = Un_Married_Population_StandardDeviation/math.sqrt(sample_size)
print("Standard Deviation for Un-Marries of 3000 samples :",Un_Married_sample_3000_sd)

############# Calculation of Z-Score & confidence Interval (CI = [mu - Z*(s.d/root(n)), mu - Z*(s.d/root(n))]) ################
alpha = 1/100
Z_3000 = abs(norm.ppf(alpha))

# Range Calculation for Married people
print("CI range for Married at 99% confidence is [{}, {}]"
      .format(Married_Population_Mean - Z_3000 *Married_sample_3000_sd,
              Married_Population_Mean + Z_3000 *Married_sample_3000_sd))

# Range Calculation for Unmarried people
print("CI range for Unmarried at 99% confidence is [{}, {}]"
      .format(Un_Married_Population_Mean - Z_3000 *Un_Married_sample_3000_sd,
              Un_Married_Population_Mean + Z_3000 *Un_Married_sample_3000_sd))





print()
print("_ "*60)

##############################################################################################################################

print("For Sample size of 3000 & 95% Confidence i.e. (alpha = 5%)")
sample_size = 3000
Married_Sample_Purchase_Mean = []
Un_married_Sample_Purchase_Mean = []
for i in range(1,1000):
    Married_Mean = df.loc[df['Marital_Status']==0,'Purchase'].sample(sample_size).mean()
    Married_Sample_Purchase_Mean.append(Married_Mean)
    Un_Married_Mean = df.loc[df['Marital_Status']==1,'Purchase'].sample(sample_size).mean()
    Un_married_Sample_Purchase_Mean.append(Un_Married_Mean)
# Plotting histogram for both Married & Un-Married for Purchases
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
sns.histplot(Married_Sample_Purchase_Mean,kde=True)
plt.title("Married vs Purchase")

plt.subplot(1,2,2)
sns.histplot(Un_married_Sample_Purchase_Mean,kde=True)
plt.title("Un-Married vs Purchase")
plt.show()

############################ for sample(n=3000) & 95% confidence calculation of CI ##########################################
# Married Sample mean Calculation & Standar deviation Calculation for Sample
Married_sample_3000_sd = Married_Population_StandardDeviation/math.sqrt(sample_size)
print("Standard Deviation for Married of 3000 samples :",Married_sample_3000_sd)

#Unmarried Sample mean Calculation & Standar deviation Calculation for Sample
Un_Married_sample_3000_sd = Un_Married_Population_StandardDeviation/math.sqrt(sample_size)
print("Standard Deviation for Un-Marries of 3000 samples :",Un_Married_sample_3000_sd)

############# Calculation of Z-Score & confidence Interval (CI = [mu - Z*(s.d/root(n)), mu - Z*(s.d/root(n))]) ################
alpha = 5/100
Z_3000 = abs(norm.ppf(alpha))

# Range Calculation for Married people
print("CI range for Married at 95% confidence is [{}, {}]"
      .format(Married_Population_Mean - Z_3000 *Married_sample_3000_sd,
              Married_Population_Mean + Z_3000 *Married_sample_3000_sd))

# Range Calculation for Unmarried people
print("CI range for Unmarried at 95% confidence is [{}, {}]"
      .format(Un_Married_Population_Mean - Z_3000 *Un_Married_sample_3000_sd,
              Un_Married_Population_Mean + Z_3000 *Un_Married_sample_3000_sd))





print()
print("_ "*60)

##############################################################################################################################



print("For Sample size of 3000 & 90% Confidence i.e. (alpha = 10%)")
sample_size = 3000
Married_Sample_Purchase_Mean = []
Un_married_Sample_Purchase_Mean = []
for i in range(1,1000):
    Married_Mean = df.loc[df['Marital_Status']==0,'Purchase'].sample(sample_size).mean()
    Married_Sample_Purchase_Mean.append(Married_Mean)
    Un_Married_Mean = df.loc[df['Marital_Status']==1,'Purchase'].sample(sample_size).mean()
    Un_married_Sample_Purchase_Mean.append(Un_Married_Mean)
# Plotting histogram for both Married & Un-Married for Purchases
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
sns.histplot(Married_Sample_Purchase_Mean,kde=True)
plt.title("Married vs Purchase")

plt.subplot(1,2,2)
sns.histplot(Un_married_Sample_Purchase_Mean,kde=True)
plt.title("Un-Married vs Purchase")
plt.show()

############################ for sample(n=3000) & 90% confidence calculation of CI ##########################################
# Married Sample mean Calculation & Standar deviation Calculation for Sample
Married_sample_3000_sd = Married_Population_StandardDeviation/math.sqrt(sample_size)
print("Standard Deviation for Married of 3000 samples :",Married_sample_3000_sd)

#Unmarried Sample mean Calculation & Standar deviation Calculation for Sample
Un_Married_sample_3000_sd = Un_Married_Population_StandardDeviation/math.sqrt(sample_size)
print("Standard Deviation for Un-Marries of 3000 samples :",Un_Married_sample_3000_sd)

############# Calculation of Z-Score & confidence Interval (CI = [mu - Z*(s.d/root(n)), mu - Z*(s.d/root(n))]) ################
alpha = 10/100
Z_3000 = abs(norm.ppf(alpha))

# Range Calculation for Married people
print("CI range for Married at 90% confidence is [{}, {}]"
      .format(Married_Population_Mean - Z_3000 *Married_sample_3000_sd,
              Married_Population_Mean + Z_3000 *Married_sample_3000_sd))

# Range Calculation for Unmarried people
print("CI range for Unmarried at 90% confidence is [{}, {}]"
      .format(Un_Married_Population_Mean - Z_3000 *Un_Married_sample_3000_sd,
              Un_Married_Population_Mean + Z_3000 *Un_Married_sample_3000_sd))





print()
print("_ "*60)

##############################################################################################################################

print("For Sample size of 30000 & 99% Confidence i.e. (alpha = 1%)")
sample_size = 30000
Married_Sample_Purchase_Mean = []
Un_married_Sample_Purchase_Mean = []
for i in range(1,1000):
    Married_Mean = df.loc[df['Marital_Status']==0,'Purchase'].sample(sample_size).mean()
    Married_Sample_Purchase_Mean.append(Married_Mean)
    Un_Married_Mean = df.loc[df['Marital_Status']==1,'Purchase'].sample(sample_size).mean()
    Un_married_Sample_Purchase_Mean.append(Un_Married_Mean)
# Plotting histogram for both Married & Un-Married for Purchases
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
sns.histplot(Married_Sample_Purchase_Mean,kde=True)
plt.title("Married vs Purchase")

plt.subplot(1,2,2)
sns.histplot(Un_married_Sample_Purchase_Mean,kde=True)
plt.title("Un-Married vs Purchase")
plt.show()

############################ for sample(n=30000) & 99% confidence calculation of CI ##########################################
# Married Sample mean Calculation & Standar deviation Calculation for Sample
Married_sample_30000_sd = Married_Population_StandardDeviation/math.sqrt(sample_size)
print("Standard Deviation for Married of 30000 samples :",Married_sample_30000_sd)

#Unmarried Sample mean Calculation & Standar deviation Calculation for Sample
Un_Married_sample_30000_sd = Un_Married_Population_StandardDeviation/math.sqrt(sample_size)
print("Standard Deviation for Un-Marries of 30000 samples :",Un_Married_sample_30000_sd)

############# Calculation of Z-Score & confidence Interval (CI = [mu - Z*(s.d/root(n)), mu - Z*(s.d/root(n))]) ################
alpha = 1/100
Z_30000 = abs(norm.ppf(alpha))

# Range Calculation for Married people
print("CI range for Married at 99% confidence is [{}, {}]"
      .format(Married_Population_Mean - Z_30000 *Married_sample_30000_sd,
              Married_Population_Mean + Z_30000 *Married_sample_30000_sd))

# Range Calculation for Unmarried people
print("CI range for Unmarried at 99% confidence is [{}, {}]"
      .format(Un_Married_Population_Mean - Z_30000 *Un_Married_sample_30000_sd,
              Un_Married_Population_Mean + Z_30000 *Un_Married_sample_30000_sd))





print()
print("_ "*60)

##############################################################################################################################

print("For Sample size of 30000 & 95% Confidence i.e. (alpha = 5%)")
sample_size = 30000
Married_Sample_Purchase_Mean = []
Un_married_Sample_Purchase_Mean = []
for i in range(1,1000):
    Married_Mean = df.loc[df['Marital_Status']==0,'Purchase'].sample(sample_size).mean()
    Married_Sample_Purchase_Mean.append(Married_Mean)
    Un_Married_Mean = df.loc[df['Marital_Status']==1,'Purchase'].sample(sample_size).mean()
    Un_married_Sample_Purchase_Mean.append(Un_Married_Mean)
# Plotting histogram for both Married & Un-Married for Purchases
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
sns.histplot(Married_Sample_Purchase_Mean,kde=True)
plt.title("Married vs Purchase")

plt.subplot(1,2,2)
sns.histplot(Un_married_Sample_Purchase_Mean,kde=True)
plt.title("Un-Married vs Purchase")
plt.show()

############################ for sample(n=30000) & 95% confidence calculation of CI ##########################################
# Married Sample mean Calculation & Standar deviation Calculation for Sample
Married_sample_30000_sd = Married_Population_StandardDeviation/math.sqrt(sample_size)
print("Standard Deviation for Married of 30000 samples :",Married_sample_30000_sd)

#Unmarried Sample mean Calculation & Standar deviation Calculation for Sample
Un_Married_sample_30000_sd = Un_Married_Population_StandardDeviation/math.sqrt(sample_size)
print("Standard Deviation for Un-Marries of 30000 samples :",Un_Married_sample_30000_sd)

############# Calculation of Z-Score & confidence Interval (CI = [mu - Z*(s.d/root(n)), mu - Z*(s.d/root(n))]) ################
alpha = 5/100
Z_30000 = abs(norm.ppf(alpha))

# Range Calculation for Married people
print("CI range for Married at 95% confidence is [{}, {}]"
      .format(Married_Population_Mean - Z_30000 *Married_sample_30000_sd,
              Married_Population_Mean + Z_30000 *Married_sample_30000_sd))

# Range Calculation for Unmarried people
print("CI range for Unmarried at 95% confidence is [{}, {}]"
      .format(Un_Married_Population_Mean - Z_30000 *Un_Married_sample_30000_sd,
              Un_Married_Population_Mean + Z_30000 *Un_Married_sample_30000_sd))





print()
print("_ "*60)

##############################################################################################################################



print("For Sample size of 30000 & 90% Confidence i.e. (alpha = 10%)")
sample_size = 30000
Married_Sample_Purchase_Mean = []
Un_married_Sample_Purchase_Mean = []
for i in range(1,1000):
    Married_Mean = df.loc[df['Marital_Status']==0,'Purchase'].sample(sample_size).mean()
    Married_Sample_Purchase_Mean.append(Married_Mean)
    Un_Married_Mean = df.loc[df['Marital_Status']==1,'Purchase'].sample(sample_size).mean()
    Un_married_Sample_Purchase_Mean.append(Un_Married_Mean)
# Plotting histogram for both Married & Un-Married for Purchases
plt.figure(figsize=(20,5))
plt.subplot(1,2,1)
sns.histplot(Married_Sample_Purchase_Mean,kde=True)
plt.title("Married vs Purchase")

plt.subplot(1,2,2)
sns.histplot(Un_married_Sample_Purchase_Mean,kde=True)
plt.title("Un-Married vs Purchase")
plt.show()

############################ for sample(n=30000) & 90% confidence calculation of CI ##########################################
# Married Sample mean Calculation & Standar deviation Calculation for Sample
Married_sample_30000_sd = Married_Population_StandardDeviation/math.sqrt(sample_size)
print("Standard Deviation for Married of 30000 samples :",Married_sample_30000_sd)

#Unmarried Sample mean Calculation & Standar deviation Calculation for Sample
Un_Married_sample_30000_sd = Un_Married_Population_StandardDeviation/math.sqrt(sample_size)
print("Standard Deviation for Un-Marries of 30000 samples :",Un_Married_sample_30000_sd)

############# Calculation of Z-Score & confidence Interval (CI = [mu - Z*(s.d/root(n)), mu - Z*(s.d/root(n))]) ################
alpha = 10/100
Z_30000 = abs(norm.ppf(alpha))

# Range Calculation for Married people
print("CI range for Married at 90% confidence is [{}, {}]"
      .format(Married_Population_Mean - Z_30000 *Married_sample_30000_sd,
              Married_Population_Mean + Z_30000 *Married_sample_30000_sd))

# Range Calculation for Unmarried people
print("CI range for Unmarried at 90% confidence is [{}, {}]"
      .format(Un_Married_Population_Mean - Z_30000 *Un_Married_sample_30000_sd,
              Un_Married_Population_Mean + Z_30000 *Un_Married_sample_30000_sd))





print()
print("_ "*60)

##############################################################################################################################
# Out:
# For Sample size of 300 & 99% Confidence i.e. (alpha = 1%)
# Standard Deviation for Married of 300 samples : 290.2540639515581
# Standard Deviation for Un-Marries of 300 samples : 289.65070515655475
# CI range for Married at 99% confidence is [8590.675694316085, 9941.139543526928]
# CI range for Unmarried at 99% confidence is [8587.346271926992, 9935.002876237755]
#
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# For Sample size of 300 & 95% Confidence i.e. (alpha = 5%)
# Standard Deviation for Married of 300 samples : 290.2540639515581
# Standard Deviation for Un-Marries of 300 samples : 289.65070515655475
# CI range for Married at 95% confidence is [8788.482169093382, 9743.333068749631]
# CI range for Unmarried at 95% confidence is [8784.741561156563, 9737.607587008184]
#
# _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _
# ...

# %% [markdown]
# ## 5.3 For Age Group Calculation of Confidence Interval

# %%
# Populatin Mean & Standard Deviation for an Age group of 0-17
Age_0_17_Population_Mean  = df.loc[df['Age']=='0-17','Purchase'].mean()
Age_0_17_Population_std  = df.loc[df['Age']=='0-17','Purchase'].std()
print("For Age group of 0 - 17 , Population mean (mu): {} & Population S.D : {}"
      .format(Age_0_17_Population_Mean,Age_0_17_Population_std))
print()

# Populatin Mean & Standard Deviation for an Age group of '18-25
Age_18_25_Population_Mean  = df.loc[df['Age']=='18-25','Purchase'].mean()
Age_18_25_Population_std  = df.loc[df['Age']=='18-25','Purchase'].std()
print("For Age group of 18 - 25 , Population mean (mu): {} & Population S.D : {}"
      .format(Age_18_25_Population_Mean,Age_18_25_Population_std))
print()
# Populatin Mean & Standard Deviation for an Age group of'26-35'
Age_26_35_Population_Mean  = df.loc[df['Age']=='26-35','Purchase'].mean()
Age_26_35_Population_std  = df.loc[df['Age']=='26-35','Purchase'].std()
print("For Age group of 26 - 35 , Population mean (mu): {} & Population S.D : {}"
      .format(Age_26_35_Population_Mean,Age_26_35_Population_std))
print()
# Populatin Mean & Standard Deviation for an Age group of'36-45'
Age_36_45_Population_Mean  = df.loc[df['Age']=='36-45','Purchase'].mean()
Age_36_45_Population_std  = df.loc[df['Age']=='36-45','Purchase'].std()
print("For Age group of 36 - 45 , Population mean (mu): {} & Population S.D : {}"
      .format(Age_36_45_Population_Mean,Age_36_45_Population_std))
print()
# Populatin Mean & Standard Deviation for an Age group of'46-50'
Age_46_50_Population_Mean  = df.loc[df['Age']=='46-50','Purchase'].mean()
Age_46_50_Population_std  = df.loc[df['Age']=='46-50','Purchase'].std()
print("For Age group of 46 - 50 , Population mean (mu): {} & Population S.D : {}"
      .format(Age_46_50_Population_Mean,Age_46_50_Population_std))
print()
# Populatin Mean & Standard Deviation for an Age group of'51-55'
Age_51_55_Population_Mean  = df.loc[df['Age']=='51-55','Purchase'].mean()
Age_51_55_Population_std  = df.loc[df['Age']=='51-55','Purchase'].std()
print("For Age group of 51 - 55 , Population mean (mu): {} & Population S.D : {}"
      .format(Age_51_55_Population_Mean,Age_51_55_Population_std))
print()
# Populatin Mean & Standard Deviation for an Age group of'55+'
Age_55_plus_Population_Mean  = df.loc[df['Age']=='55+','Purchase'].mean()
Age_55_plus_Population_std  = df.loc[df['Age']=='55+','Purchase'].std()
print("For Age group of 55+ , Population mean (mu): {} & Population S.D : {}"
      .format(Age_55_plus_Population_Mean,Age_55_plus_Population_std))
print()
# Out:
# For Age group of 0 - 17 , Population mean (mu): 8933.464640444974 & Population S.D : 5111.11404600277
#
# For Age group of 18 - 25 , Population mean (mu): 9169.663606261289 & Population S.D : 5034.32199717658
#
# For Age group of 26 - 35 , Population mean (mu): 9252.690632869888 & Population S.D : 5010.527303002956
#
# For Age group of 36 - 45 , Population mean (mu): 9331.350694917874 & Population S.D : 5022.923879204662
#
# For Age group of 46 - 50 , Population mean (mu): 9208.625697468327 & Population S.D : 4967.216367142941
#
# For Age group of 51 - 55 , Population mean (mu): 9534.808030960236 & Population S.D : 5087.368079602135
#
# For Age group of 55+ , Population mean (mu): 9336.280459449405 & Population S.D : 5011.4939956034605

# %%
print("For Sample size of 300 & 99% Confidence i.e. (alpha = 1%)")
sample_size = 300
Age_0_17__Sample_Purchase_Mean = []
Age_18_25__Sample_Purchase_Mean = []
Age_26_35__Sample_Purchase_Mean = []
Age_36_45__Sample_Purchase_Mean = []
Age_46_50__Sample_Purchase_Mean = []
Age_51_55__Sample_Purchase_Mean = []
Age_55_plus__Sample_Purchase_Mean = []
for i in range(1,1000):
    Age_0_17__Sample_Purchase_Mean.append(df.loc[df['Age']=='0-17','Purchase'].sample(sample_size).mean())
    Age_18_25__Sample_Purchase_Mean.append(df.loc[df['Age']=='18-25','Purchase'].sample(sample_size).mean())
    Age_26_35__Sample_Purchase_Mean.append(df.loc[df['Age']=='26-35','Purchase'].sample(sample_size).mean())
    Age_36_45__Sample_Purchase_Mean.append(df.loc[df['Age']=='36-45','Purchase'].sample(sample_size).mean())
    Age_46_50__Sample_Purchase_Mean.append(df.loc[df['Age']=='46-50','Purchase'].sample(sample_size).mean())
    Age_51_55__Sample_Purchase_Mean.append(df.loc[df['Age']=='51-55','Purchase'].sample(sample_size).mean())
    Age_55_plus__Sample_Purchase_Mean.append(df.loc[df['Age']=='55+','Purchase'].sample(sample_size).mean())
    
# Plotting histogram for both Married & Un-Married for Purchases
plt.figure(figsize=(20,5))
plt.subplot(1,7,1)
sns.histplot(Age_0_17__Sample_Purchase_Mean,kde=True)
plt.title("Age 0-17 vs Purchase")

plt.subplot(1,7,2)
sns.histplot(Age_18_25__Sample_Purchase_Mean,kde=True)
plt.title("Age 18-25 vs Purchase")

plt.subplot(1,7,3)
sns.histplot(Age_26_35__Sample_Purchase_Mean,kde=True)
plt.title("Age 26-35 vs Purchase")

plt.subplot(1,7,4)
sns.histplot(Age_36_45__Sample_Purchase_Mean,kde=True)
plt.title("Age 36-45 vs Purchase")

plt.subplot(1,7,5)
sns.histplot(Age_46_50__Sample_Purchase_Mean,kde=True)
plt.title("Age 46-50 vs Purchase")

plt.subplot(1,7,6)
sns.histplot(Age_51_55__Sample_Purchase_Mean,kde=True)
plt.title("Age 51-55 vs Purchase")

plt.subplot(1,7,7)
sns.histplot(Age_55_plus__Sample_Purchase_Mean,kde=True)
plt.title("Age 55 + vs Purchase")
plt.show()

############################ for sample(n=300) & 99% confidence calculation of CI ##########################################
# Age Group 0-17 mean Calculation & Standar deviation Calculation for Sample
Age_0_17_sample_300_sd = Age_0_17_Population_std/math.sqrt(sample_size)
print("Standard Deviation for Age group 0-17 samples :",Age_0_17_sample_300_sd)
# Age Group 18-25 mean Calculation & Standar deviation Calculation for Sample
Age_18_25_sample_300_sd = Age_18_25_Population_std/math.sqrt(sample_size)
print("Standard Deviation for Age group 18-25 samples :",Age_18_25_sample_300_sd)
# Age Group_26-35 mean Calculation & Standar deviation Calculation for Sample
Age_26_35_sample_300_sd = Age_26_35_Population_std/math.sqrt(sample_size)
print("Standard Deviation for Age group 26-35 samples :",Age_26_35_sample_300_sd)
# Age Group 36-45 mean Calculation & Standar deviation Calculation for Sample
Age_36_45_sample_300_sd = Age_36_45_Population_std/math.sqrt(sample_size)
print("Standard Deviation for Age group 36-45 samples :",Age_36_45_sample_300_sd)
# Age Group 46-50 mean Calculation & Standar deviation Calculation for Sample
Age_46_50_sample_300_sd = Age_46_50_Population_std/math.sqrt(sample_size)
print("Standard Deviation for Age group 46-50 samples :",Age_46_50_sample_300_sd)
# Age Group 51-55 mean Calculation & Standar deviation Calculation for Sample
Age_51_55_sample_300_sd = Age_51_55_Population_std/math.sqrt(sample_size)
print("Standard Deviation for Age group 51-55 samples :",Age_51_55_sample_300_sd)
# Age Group 55_plus mean Calculation & Standar deviation Calculation for Sample
Age_55_plus_sample_300_sd = Age_55_plus_Population_std/math.sqrt(sample_size)
print("Standard Deviation for Age group 55_plus samples :",Age_55_plus_sample_300_sd)

############# Calculation of Z-Score & confidence Interval (CI = [mu - Z*(s.d/root(n)), mu - Z*(s.d/root(n))]) ################
alpha = 1/100
Z_300 = abs(norm.ppf(alpha))

# Range Calculation for Age group of 0-17 people
print("CI range for Age group of 0-17 people at 99% confidence is [{}, {}]"
      .format(Age_0_17_Population_Mean  - Z_300 *Age_0_17_sample_300_sd,
              Age_0_17_Population_Mean  + Z_300 *Age_0_17_sample_300_sd))
# Range Calculation for Age group of 18-25 people
print("CI range for Age group of 18-25 people at 99% confidence is [{}, {}]"
      .format(Age_18_25_Population_Mean  - Z_300 *Age_18_25_sample_300_sd,
              Age_18_25_Population_Mean  + Z_300 *Age_18_25_sample_300_sd))
# Range Calculation for Age group of 26-35 people
print("CI range for Age group of 26-35 people at 99% confidence is [{}, {}]"
      .format(Age_26_35_Population_Mean  - Z_300 *Age_26_35_sample_300_sd,
              Age_26_35_Population_Mean  + Z_300 *Age_26_35_sample_300_sd))
# Range Calculation for Age group of 36-45 people
print("CI range for Age group of 36-45 people at 99% confidence is [{}, {}]"
      .format(Age_36_45_Population_Mean  - Z_300 *Age_36_45_sample_300_sd,
              Age_36_45_Population_Mean  + Z_300 *Age_36_45_sample_300_sd))
# Range Calculation for Age group of 46-50 people
print("CI range for Age group of 46-50 people at 99% confidence is [{}, {}]"
      .format(Age_46_50_Population_Mean  - Z_300 *Age_46_50_sample_300_sd,
              Age_46_50_Population_Mean  + Z_300 *Age_46_50_sample_300_sd))
# Range Calculation for Age group of 51-55 people
print("CI range for Age group of 51-55 people at 99% confidence is [{}, {}]"
      .format(Age_51_55_Population_Mean  - Z_300 *Age_51_55_sample_300_sd,
              Age_51_55_Population_Mean  + Z_300 *Age_51_55_sample_300_sd))
# Range Calculation for Age group of 55_plus people
print("CI range for Age group of 55_plus people at 99% confidence is [{}, {}]"
      .format(Age_55_plus_Population_Mean  - Z_300 *Age_55_plus_sample_300_sd,
              Age_55_plus_Population_Mean  + Z_300 *Age_55_plus_sample_300_sd))






print()
print("_ "*60)

##############################################################################################################################

print("For Sample size of 300 & 95% Confidence i.e. (alpha = 5%)")
sample_size = 300
Age_0_17__Sample_Purchase_Mean = []
Age_18_25__Sample_Purchase_Mean = []
Age_26_35__Sample_Purchase_Mean = []
Age_36_45__Sample_Purchase_Mean = []
Age_46_50__Sample_Purchase_Mean = []
Age_51_55__Sample_Purchase_Mean = []
Age_55_plus__Sample_Purchase_Mean = []
for i in range(1,1000):
    Age_0_17__Sample_Purchase_Mean.append(df.loc[df['Age']=='0-17','Purchase'].sample(sample_size).mean())
    Age_18_25__Sample_Purchase_Mean.append(df.loc[df['Age']=='18-25','Purchase'].sample(sample_size).mean())
    Age_26_35__Sample_Purchase_Mean.append(df.loc[df['Age']=='26-35','Purchase'].sample(sample_size).mean())
    Age_36_45__Sample_Purchase_Mean.append(df.loc[df['Age']=='36-45','Purchase'].sample(sample_size).mean())
    Age_46_50__Sample_Purchase_Mean.append(df.loc[df['Age']=='46-50','Purchase'].sample(sample_size).mean())
    Age_51_55__Sample_Purchase_Mean.append(df.loc[df['Age']=='51-55','Purchase'].sample(sample_size).mean())
    Age_55_plus__Sample_Purchase_Mean.append(df.loc[df['Age']=='55+','Purchase'].sample(sample_size).mean())
    
# Plotting histogram for both Married & Un-Married for Purchases
plt.figure(figsize=(20,5))
plt.subplot(1,7,1)
sns.histplot(Age_0_17__Sample_Purchase_Mean,kde=True)
plt.title("Age 0-17 vs Purchase")

plt.subplot(1,7,2)
sns.histplot(Age_18_25__Sample_Purchase_Mean,kde=True)
plt.title("Age 18-25 vs Purchase")

plt.subplot(1,7,3)
sns.histplot(Age_26_35__Sample_Purchase_Mean,kde=True)
plt.title("Age 26-35 vs Purchase")

plt.subplot(1,7,4)
sns.histplot(Age_36_45__Sample_Purchase_Mean,kde=True)
plt.title("Age 36-45 vs Purchase")

plt.subplot(1,7,5)
sns.histplot(Age_46_50__Sample_Purchase_Mean,kde=True)
plt.title("Age 46-50 vs Purchase")

plt.subplot(1,7,6)
sns.histplot(Age_51_55__Sample_Purchase_Mean,kde=True)
plt.title("Age 51-55 vs Purchase")

plt.subplot(1,7,7)
sns.histplot(Age_55_plus__Sample_Purchase_Mean,kde=True)
plt.title("Age 55 + vs Purchase")
plt.show()

############################ for sample(n=300) & 95% confidence calculation of CI ##########################################
# Age Group 0-17 mean Calculation & Standar deviation Calculation for Sample
Age_0_17_sample_300_sd = Age_0_17_Population_std/math.sqrt(sample_size)
print("Standard Deviation for Age group 0-17 samples :",Age_0_17_sample_300_sd)
# Age Group 18-25 mean Calculation & Standar deviation Calculation for Sample
Age_18_25_sample_300_sd = Age_18_25_Population_std/math.sqrt(sample_size)
print("Standard Deviation for Age group 18-25 samples :",Age_18_25_sample_300_sd)
# Age Group_26-35 mean Calculation & Standar deviation Calculation for Sample
Age_26_35_sample_300_sd = Age_26_35_Population_std/math.sqrt(sample_size)
print("Standard Deviation for Age group 26-35 samples :",Age_26_35_sample_300_sd)
# Age Group 36-45 mean Calculation & Standar deviation Calculation for Sample
Age_36_45_sample_300_sd = Age_36_45_Population_std/math.sqrt(sample_size)
print("Standard Deviation for Age group 36-45 samples :",Age_36_45_sample_300_sd)
# Age Group 46-50 mean Calculation & Standar deviation Calculation for Sample
Age_46_50_sample_300_sd = Age_46_50_Population_std/math.sqrt(sample_size)
print("Standard Deviation for Age group 46-50 samples :",Age_46_50_sample_300_sd)
# Age Group 51-55 mean Calculation & Standar deviation Calculation for Sample
Age_51_55_sample_300_sd = Age_51_55_Population_std/math.sqrt(sample_size)
print("Standard Deviation for Age group 51-55 samples :",Age_51_55_sample_300_sd)
# Age Group 55_plus mean Calculation & Standar deviation Calculation for Sample
Age_55_plus_sample_300_sd = Age_55_plus_Population_std/math.sqrt(sample_size)
print("Standard Deviation for Age group 55_plus samples :",Age_55_plus_sample_300_sd)

############# Calculation of Z-Score & confidence Interval (CI = [mu - Z*(s.d/root(n)), mu - Z*(s.d/root(n))]) ################
alpha = 5/100
Z_300 = abs(norm.ppf(alpha))

# Range Calculation for Age group of 0-17 people
print("CI range for Age group of 0-17 people at 95% confidence is [{}, {}]"
      .format(Age_0_17_Population_Mean  - Z_300 *Age_0_17_sample_300_sd,
              Age_0_17_Population_Mean  + Z_300 *Age_0_17_sample_300_sd))
# Range Calculation for Age group of 18-25 people
print("CI range for Age group of 18-25 people at 95% confidence is [{}, {}]"
      .format(Age_18_25_Population_Mean  - Z_300 *Age_18_25_sample_300_sd,
              Age_18_25_Population_Mean  + Z_300 *Age_18_25_sample_300_sd))
# Range Calculation for Age group of 26-35 people
print("CI range for Age group of 26-35 people at 95% confidence is [{}, {}]"
      .format(Age_26_35_Population_Mean  - Z_300 *Age_26_35_sample_300_sd,
              Age_26_35_Population_Mean  + Z_300 *Age_26_35_sample_300_sd))
# Range Calculation for Age group of 36-45 people
print("CI range for Age group of 36-45 people at 95% confidence is [{}, {}]"
      .format(Age_36_45_Population_Mean  - Z_300 *Age_36_45_sample_300_sd,
              Age_36_45_Population_Mean  + Z_300 *Age_36_45_sample_300_sd))
# Range Calculation for Age group of 46-50 people
print("CI range for Age group of 46-50 people at 95% confidence is [{}, {}]"
      .format(Age_46_50_Population_Mean  - Z_300 *Age_46_50_sample_300_sd,
              Age_46_50_Population_Mean  + Z_300 *Age_46_50_sample_300_sd))
# Range Calculation for Age group of 51-55 people
print("CI range for Age group of 51-55 people at 95% confidence is [{}, {}]"
      .format(Age_51_55_Population_Mean  - Z_300 *Age_51_55_sample_300_sd,
              Age_51_55_Population_Mean  + Z_300 *Age_51_55_sample_300_sd))
# Range Calculation for Age group of 55_plus people
print("CI range for Age group of 55_plus people at 95% confidence is [{}, {}]"
      .format(Age_55_plus_Population_Mean  - Z_300 *Age_55_plus_sample_300_sd,
              Age_55_plus_Population_Mean  + Z_300 *Age_55_plus_sample_300_sd))






print()
print("_ "*60)

##############################################################################################################################

print("For Sample size of 300 & 90% Confidence i.e. (alpha = 10%)")
sample_size = 300
Age_0_17__Sample_Purchase_Mean = []
Age_18_25__Sample_Purchase_Mean = []
Age_26_35__Sample_Purchase_Mean = []
Age_36_45__Sample_Purchase_Mean = []
Age_46_50__Sample_Purchase_Mean = []
Age_51_55__Sample_Purchase_Mean = []
Age_55_plus__Sample_Purchase_Mean = []
for i in range(1,1000):
    Age_0_17__Sample_Purchase_Mean.append(df.loc[df['Age']=='0-17','Purchase'].sample(sample_size).mean())
    Age_18_25__Sample_Purchase_Mean.append(df.loc[df['Age']=='18-25','Purchase'].sample(sample_size).mean())
    Age_26_35__Sample_Purchase_Mean.append(df.loc[df['Age']=='26-35','Purchase'].sample(sample_size).mean())
    Age_36_45__Sample_Purchase_Mean.append(df.loc[df['Age']=='36-45','Purchase'].sample(sample_size).mean())
    Age_46_50__Sample_Purchase_Mean.append(df.loc[df['Age']=='46-50','Purchase'].sample(sample_size).mean())
    Age_51_55__Sample_Purchase_Mean.append(df.loc[df['Age']=='51-55','Purchase'].sample(sample_size).mean())
    Age_55_plus__Sample_Purchase_Mean.append(df.loc[df['Age']=='55+','Purchase'].sample(sample_size).mean())
    
# Plotting histogram for both Married & Un-Married for Purchases
plt.figure(figsize=(20,5))
plt.subplot(1,7,1)
sns.histplot(Age_0_17__Sample_Purchase_Mean,kde=True)
plt.title("Age 0-17 vs Purchase")

plt.subplot(1,7,2)
sns.histplot(Age_18_25__Sample_Purchase_Mean,kde=True)
plt.title("Age 18-25 vs Purchase")

plt.subplot(1,7,3)
sns.histplot(Age_26_35__Sample_Purchase_Mean,kde=True)
plt.title("Age 26-35 vs Purchase")

plt.subplot(1,7,4)
sns.histplot(Age_36_45__Sample_Purchase_Mean,kde=True)
plt.title("Age 36-45 vs Purchase")

plt.subplot(1,7,5)
sns.histplot(Age_46_50__Sample_Purchase_Mean,kde=True)
plt.title("Age 46-50 vs Purchase")

plt.subplot(1,7,6)
sns.histplot(Age_51_55__Sample_Purchase_Mean,kde=True)
plt.title("Age 51-55 vs Purchase")

plt.subplot(1,7,7)
sns.histplot(Age_55_plus__Sample_Purchase_Mean,kde=True)
plt.title("Age 55 + vs Purchase")
plt.show()

############################ for sample(n=300) & 90% confidence calculation of CI ##########################################
# Age Group 0-17 mean Calculation & Standar deviation Calculation for Sample
Age_0_17_sample_300_sd = Age_0_17_Population_std/math.sqrt(sample_size)
print("Standard Deviation for Age group 0-17 samples :",Age_0_17_sample_300_sd)
# Age Group 18-25 mean Calculation & Standar deviation Calculation for Sample
Age_18_25_sample_300_sd = Age_18_25_Population_std/math.sqrt(sample_size)
print("Standard Deviation for Age group 18-25 samples :",Age_18_25_sample_300_sd)
# Age Group_26-35 mean Calculation & Standar deviation Calculation for Sample
Age_26_35_sample_300_sd = Age_26_35_Population_std/math.sqrt(sample_size)
print("Standard Deviation for Age group 26-35 samples :",Age_26_35_sample_300_sd)
# Age Group 36-45 mean Calculation & Standar deviation Calculation for Sample
Age_36_45_sample_300_sd = Age_36_45_Population_std/math.sqrt(sample_size)
print("Standard Deviation for Age group 36-45 samples :",Age_36_45_sample_300_sd)
# Age Group 46-50 mean Calculation & Standar deviation Calculation for Sample
Age_46_50_sample_300_sd = Age_46_50_Population_std/math.sqrt(sample_size)
print("Standard Deviation for Age group 46-50 samples :",Age_46_50_sample_300_sd)
# Age Group 51-55 mean Calculation & Standar deviation Calculation for Sample
Age_51_55_sample_300_sd = Age_51_55_Population_std/math.sqrt(sample_size)
print("Standard Deviation for Age group 51-55 samples :",Age_51_55_sample_300_sd)
# Age Group 55_plus mean Calculation & Standar deviation Calculation for Sample
Age_55_plus_sample_300_sd = Age_55_plus_Population_std/math.sqrt(sample_size)
print("Standard Deviation for Age group 55_plus samples :",Age_55_plus_sample_300_sd)

############# Calculation of Z-Score & confidence Interval (CI = [mu - Z*(s.d/root(n)), mu - Z*(s.d/root(n))]) ################
alpha = 10/100
Z_300 = abs(norm.ppf(alpha))

# Range Calculation for Age group of 0-17 people
print("CI range for Age group of 0-17 people at 90% confidence is [{}, {}]"
      .format(Age_0_17_Population_Mean  - Z_300 *Age_0_17_sample_300_sd,
              Age_0_17_Population_Mean  + Z_300 *Age_0_17_sample_300_sd))
# Range Calculation for Age group of 18-25 people
print("CI range for Age group of 18-25 people at 90% confidence is [{}, {}]"
      .format(Age_18_25_Population_Mean  - Z_300 *Age_18_25_sample_300_sd,
              Age_18_25_Population_Mean  + Z_300 *Age_18_25_sample_300_sd))
# Range Calculation for Age group of 26-35 people
print("CI range for Age group of 26-35 people at 90% confidence is [{}, {}]"
      .format(Age_26_35_Population_Mean  - Z_300 *Age_26_35_sample_300_sd,
              Age_26_35_Population_Mean  + Z_300 *Age_26_35_sample_300_sd))
# Range Calculation for Age group of 36-45 people
print("CI range for Age group of 36-45 people at 90% confidence is [{}, {}]"
      .format(Age_36_45_Population_Mean  - Z_300 *Age_36_45_sample_300_sd,
              Age_36_45_Population_Mean  + Z_300 *Age_36_45_sample_300_sd))
# Range Calculation for Age group of 46-50 people
print("CI range for Age group of 46-50 people at 90% confidence is [{}, {}]"
      .format(Age_46_50_Population_Mean  - Z_300 *Age_46_50_sample_300_sd,
              Age_46_50_Population_Mean  + Z_300 *Age_46_50_sample_300_sd))
# Range Calculation for Age group of 51-55 people
print("CI range for Age group of 51-55 people at 90% confidence is [{}, {}]"
      .format(Age_51_55_Population_Mean  - Z_300 *Age_51_55_sample_300_sd,
              Age_51_55_Population_Mean  + Z_300 *Age_51_55_sample_300_sd))
# Range Calculation for Age group of 55_plus people
print("CI range for Age group of 55_plus people at 90% confidence is [{}, {}]"
      .format(Age_55_plus_Population_Mean  - Z_300 *Age_55_plus_sample_300_sd,
              Age_55_plus_Population_Mean  + Z_300 *Age_55_plus_sample_300_sd))






print()
print("_ "*60)

##############################################################################################################################

print("For Sample size of 3000 & 99% Confidence i.e. (alpha = 1%)")
sample_size = 3000
Age_0_17__Sample_Purchase_Mean = []
Age_18_25__Sample_Purchase_Mean = []
Age_26_35__Sample_Purchase_Mean = []
Age_36_45__Sample_Purchase_Mean = []
Age_46_50__Sample_Purchase_Mean = []
Age_51_55__Sample_Purchase_Mean = []
Age_55_plus__Sample_Purchase_Mean = []
for i in range(1,1000):
    Age_0_17__Sample_Purchase_Mean.append(df.loc[df['Age']=='0-17','Purchase'].sample(sample_size).mean())
    Age_18_25__Sample_Purchase_Mean.append(df.loc[df['Age']=='18-25','Purchase'].sample(sample_size).mean())
    Age_26_35__Sample_Purchase_Mean.append(df.loc[df['Age']=='26-35','Purchase'].sample(sample_size).mean())
    Age_36_45__Sample_Purchase_Mean.append(df.loc[df['Age']=='36-45','Purchase'].sample(sample_size).mean())
    Age_46_50__Sample_Purchase_Mean.append(df.loc[df['Age']=='46-50','Purchase'].sample(sample_size).mean())
    Age_51_55__Sample_Purchase_Mean.append(df.loc[df['Age']=='51-55','Purchase'].sample(sample_size).mean())
    Age_55_plus__Sample_Purchase_Mean.append(df.loc[df['Age']=='55+','Purchase'].sample(sample_size).mean())
    
# Plotting histogram for both Married & Un-Married for Purchases
plt.figure(figsize=(20,5))
plt.subplot(1,7,1)
sns.histplot(Age_0_17__Sample_Purchase_Mean,kde=True)
plt.title("Age 0-17 vs Purchase")

plt.subplot(1,7,2)
sns.histplot(Age_18_25__Sample_Purchase_Mean,kde=True)
plt.title("Age 18-25 vs Purchase")

plt.subplot(1,7,3)
sns.histplot(Age_26_35__Sample_Purchase_Mean,kde=True)
plt.title("Age 26-35 vs Purchase")

plt.subplot(1,7,4)
sns.histplot(Age_36_45__Sample_Purchase_Mean,kde=True)
plt.title("Age 36-45 vs Purchase")

plt.subplot(1,7,5)
sns.histplot(Age_46_50__Sample_Purchase_Mean,kde=True)
plt.title("Age 46-50 vs Purchase")

plt.subplot(1,7,6)
sns.histplot(Age_51_55__Sample_Purchase_Mean,kde=True)
plt.title("Age 51-55 vs Purchase")

plt.subplot(1,7,7)
sns.histplot(Age_55_plus__Sample_Purchase_Mean,kde=True)
plt.title("Age 55 + vs Purchase")
plt.show()

############################ for sample(n=3000) & 99% confidence calculation of CI ##########################################
# Age Group 0-17 mean Calculation & Standar deviation Calculation for Sample
Age_0_17_sample_3000_sd = Age_0_17_Population_std/math.sqrt(sample_size)
print("Standard Deviation for Age group 0-17 samples :",Age_0_17_sample_3000_sd)
# Age Group 18-25 mean Calculation & Standar deviation Calculation for Sample
Age_18_25_sample_3000_sd = Age_18_25_Population_std/math.sqrt(sample_size)
print("Standard Deviation for Age group 18-25 samples :",Age_18_25_sample_3000_sd)
# Age Group_26-35 mean Calculation & Standar deviation Calculation for Sample
Age_26_35_sample_3000_sd = Age_26_35_Population_std/math.sqrt(sample_size)
print("Standard Deviation for Age group 26-35 samples :",Age_26_35_sample_3000_sd)
# Age Group 36-45 mean Calculation & Standar deviation Calculation for Sample
Age_36_45_sample_3000_sd = Age_36_45_Population_std/math.sqrt(sample_size)
print("Standard Deviation for Age group 36-45 samples :",Age_36_45_sample_3000_sd)
# Age Group 46-50 mean Calculation & Standar deviation Calculation for Sample
Age_46_50_sample_3000_sd = Age_46_50_Population_std/math.sqrt(sample_size)
print("Standard Deviation for Age group 46-50 samples :",Age_46_50_sample_3000_sd)
# Age Group 51-55 mean Calculation & Standar deviation Calculation for Sample
Age_51_55_sample_3000_sd = Age_51_55_Population_std/math.sqrt(sample_size)
print("Standard Deviation for Age group 51-55 samples :",Age_51_55_sample_3000_sd)
# Age Group 55_plus mean Calculation & Standar deviation Calculation for Sample
Age_55_plus_sample_3000_sd = Age_55_plus_Population_std/math.sqrt(sample_size)
print("Standard Deviation for Age group 55_plus samples :",Age_55_plus_sample_3000_sd)

############# Calculation of Z-Score & confidence Interval (CI = [mu - Z*(s.d/root(n)), mu - Z*(s.d/root(n))]) ################
alpha = 1/100
Z_3000 = abs(norm.ppf(alpha))

# Range Calculation for Age group of 0-17 people
print("CI range for Age group of 0-17 people at 99% confidence is [{}, {}]"
      .format(Age_0_17_Population_Mean  - Z_3000 *Age_0_17_sample_3000_sd,
              Age_0_17_Population_Mean  + Z_3000 *Age_0_17_sample_3000_sd))
# Range Calculation for Age group of 18-25 people
print("CI range for Age group of 18-25 people at 99% confidence is [{}, {}]"
      .format(Age_18_25_Population_Mean  - Z_3000 *Age_18_25_sample_3000_sd,
              Age_18_25_Population_Mean  + Z_3000 *Age_18_25_sample_3000_sd))
# Range Calculation for Age group of 26-35 people
print("CI range for Age group of 26-35 people at 99% confidence is [{}, {}]"
      .format(Age_26_35_Population_Mean  - Z_3000 *Age_26_35_sample_3000_sd,
              Age_26_35_Population_Mean  + Z_3000 *Age_26_35_sample_3000_sd))
# Range Calculation for Age group of 36-45 people
print("CI range for Age group of 36-45 people at 99% confidence is [{}, {}]"
      .format(Age_36_45_Population_Mean  - Z_3000 *Age_36_45_sample_3000_sd,
              Age_36_45_Population_Mean  + Z_3000 *Age_36_45_sample_3000_sd))
# Range Calculation for Age group of 46-50 people
print("CI range for Age group of 46-50 people at 99% confidence is [{}, {}]"
      .format(Age_46_50_Population_Mean  - Z_3000 *Age_46_50_sample_3000_sd,
              Age_46_50_Population_Mean  + Z_3000 *Age_46_50_sample_3000_sd))
# Range Calculation for Age group of 51-55 people
print("CI range for Age group of 51-55 people at 99% confidence is [{}, {}]"
      .format(Age_51_55_Population_Mean  - Z_3000 *Age_51_55_sample_3000_sd,
              Age_51_55_Population_Mean  + Z_3000 *Age_51_55_sample_3000_sd))
# Range Calculation for Age group of 55_plus people
print("CI range for Age group of 55_plus people at 99% confidence is [{}, {}]"
      .format(Age_55_plus_Population_Mean  - Z_3000 *Age_55_plus_sample_3000_sd,
              Age_55_plus_Population_Mean  + Z_3000 *Age_55_plus_sample_3000_sd))






print()
print("_ "*60)

##############################################################################################################################

print("For Sample size of 3000 & 95% Confidence i.e. (alpha = 5%)")
sample_size = 3000
Age_0_17__Sample_Purchase_Mean = []
Age_18_25__Sample_Purchase_Mean = []
Age_26_35__Sample_Purchase_Mean = []
Age_36_45__Sample_Purchase_Mean = []
Age_46_50__Sample_Purchase_Mean = []
Age_51_55__Sample_Purchase_Mean = []
Age_55_plus__Sample_Purchase_Mean = []
for i in range(1,1000):
    Age_0_17__Sample_Purchase_Mean.append(df.loc[df['Age']=='0-17','Purchase'].sample(sample_size).mean())
    Age_18_25__Sample_Purchase_Mean.append(df.loc[df['Age']=='18-25','Purchase'].sample(sample_size).mean())
    Age_26_35__Sample_Purchase_Mean.append(df.loc[df['Age']=='26-35','Purchase'].sample(sample_size).mean())
    Age_36_45__Sample_Purchase_Mean.append(df.loc[df['Age']=='36-45','Purchase'].sample(sample_size).mean())
    Age_46_50__Sample_Purchase_Mean.append(df.loc[df['Age']=='46-50','Purchase'].sample(sample_size).mean())
    Age_51_55__Sample_Purchase_Mean.append(df.loc[df['Age']=='51-55','Purchase'].sample(sample_size).mean())
    Age_55_plus__Sample_Purchase_Mean.append(df.loc[df['Age']=='55+','Purchase'].sample(sample_size).mean())
    
# Plotting histogram for both Married & Un-Married for Purchases
plt.figure(figsize=(20,5))
plt.subplot(1,7,1)
sns.histplot(Age_0_17__Sample_Purchase_Mean,kde=True)
plt.title("Age 0-17 vs Purchase")

plt.subplot(1,7,2)
sns.histplot(Age_18_25__Sample_Purchase_Mean,kde=True)
plt.title("Age 18-25 vs Purchase")

plt.subplot(1,7,3)
sns.histplot(Age_26_35__Sample_Purchase_Mean,kde=True)
plt.title("Age 26-35 vs Purchase")

plt.subplot(1,7,4)
sns.histplot(Age_36_45__Sample_Purchase_Mean,kde=True)
plt.title("Age 36-45 vs Purchase")

plt.subplot(1,7,5)
sns.histplot(Age_46_50__Sample_Purchase_Mean,kde=True)
plt.title("Age 46-50 vs Purchase")

plt.subplot(1,7,6)
sns.histplot(Age_51_55__Sample_Purchase_Mean,kde=True)
plt.title("Age 51-55 vs Purchase")

plt.subplot(1,7,7)
sns.histplot(Age_55_plus__Sample_Purchase_Mean,kde=True)
plt.title("Age 55 + vs Purchase")
plt.show()

############################ for sample(n=3000) & 95% confidence calculation of CI ##########################################
# Age Group 0-17 mean Calculation & Standar deviation Calculation for Sample
Age_0_17_sample_3000_sd = Age_0_17_Population_std/math.sqrt(sample_size)
print("Standard Deviation for Age group 0-17 samples :",Age_0_17_sample_3000_sd)
# Age Group 18-25 mean Calculation & Standar deviation Calculation for Sample
Age_18_25_sample_3000_sd = Age_18_25_Population_std/math.sqrt(sample_size)
print("Standard Deviation for Age group 18-25 samples :",Age_18_25_sample_3000_sd)
# Age Group_26-35 mean Calculation & Standar deviation Calculation for Sample
Age_26_35_sample_3000_sd = Age_26_35_Population_std/math.sqrt(sample_size)
print("Standard Deviation for Age group 26-35 samples :",Age_26_35_sample_3000_sd)
# Age Group 36-45 mean Calculation & Standar deviation Calculation for Sample
Age_36_45_sample_3000_sd = Age_36_45_Population_std/math.sqrt(sample_size)
print("Standard Deviation for Age group 36-45 samples :",Age_36_45_sample_3000_sd)
# Age Group 46-50 mean Calculation & Standar deviation Calculation for Sample
Age_46_50_sample_3000_sd = Age_46_50_Population_std/math.sqrt(sample_size)
print("Standard Deviation for Age group 46-50 samples :",Age_46_50_sample_3000_sd)
# Age Group 51-55 mean Calculation & Standar deviation Calculation for Sample
Age_51_55_sample_3000_sd = Age_51_55_Population_std/math.sqrt(sample_size)
print("Standard Deviation for Age group 51-55 samples :",Age_51_55_sample_3000_sd)
# Age Group 55_plus mean Calculation & Standar deviation Calculation for Sample
Age_55_plus_sample_3000_sd = Age_55_plus_Population_std/math.sqrt(sample_size)
print("Standard Deviation for Age group 55_plus samples :",Age_55_plus_sample_3000_sd)

############# Calculation of Z-Score & confidence Interval (CI = [mu - Z*(s.d/root(n)), mu - Z*(s.d/root(n))]) ################
alpha = 5/100
Z_3000 = abs(norm.ppf(alpha))

# Range Calculation for Age group of 0-17 people
print("CI range for Age group of 0-17 people at 95% confidence is [{}, {}]"
      .format(Age_0_17_Population_Mean  - Z_3000 *Age_0_17_sample_3000_sd,
              Age_0_17_Population_Mean  + Z_3000 *Age_0_17_sample_3000_sd))
# Range Calculation for Age group of 18-25 people
print("CI range for Age group of 18-25 people at 95% confidence is [{}, {}]"
      .format(Age_18_25_Population_Mean  - Z_3000 *Age_18_25_sample_3000_sd,
              Age_18_25_Population_Mean  + Z_3000 *Age_18_25_sample_3000_sd))
# Range Calculation for Age group of 26-35 people
print("CI range for Age group of 26-35 people at 95% confidence is [{}, {}]"
      .format(Age_26_35_Population_Mean  - Z_3000 *Age_26_35_sample_3000_sd,
              Age_26_35_Population_Mean  + Z_3000 *Age_26_35_sample_3000_sd))
# Range Calculation for Age group of 36-45 people
print("CI range for Age group of 36-45 people at 95% confidence is [{}, {}]"
      .format(Age_36_45_Population_Mean  - Z_3000 *Age_36_45_sample_3000_sd,
              Age_36_45_Population_Mean  + Z_3000 *Age_36_45_sample_3000_sd))
# Range Calculation for Age group of 46-50 people
print("CI range for Age group of 46-50 people at 95% confidence is [{}, {}]"
      .format(Age_46_50_Population_Mean  - Z_3000 *Age_46_50_sample_3000_sd,
              Age_46_50_Population_Mean  + Z_3000 *Age_46_50_sample_3000_sd))
# Range Calculation for Age group of 51-55 people
print("CI range for Age group of 51-55 people at 95% confidence is [{}, {}]"
      .format(Age_51_55_Population_Mean  - Z_3000 *Age_51_55_sample_3000_sd,
              Age_51_55_Population_Mean  + Z_3000 *Age_51_55_sample_3000_sd))
# Range Calculation for Age group of 55_plus people
print("CI range for Age group of 55_plus people at 95% confidence is [{}, {}]"
      .format(Age_55_plus_Population_Mean  - Z_3000 *Age_55_plus_sample_3000_sd,
              Age_55_plus_Population_Mean  + Z_3000 *Age_55_plus_sample_3000_sd))






print()
print("_ "*60)

########################################################################################################################

print("For Sample size of 3000 & 90% Confidence i.e. (alpha = 10%)")
sample_size = 3000
Age_0_17__Sample_Purchase_Mean = []
Age_18_25__Sample_Purchase_Mean = []
Age_26_35__Sample_Purchase_Mean = []
Age_36_45__Sample_Purchase_Mean = []
Age_46_50__Sample_Purchase_Mean = []
Age_51_55__Sample_Purchase_Mean = []
Age_55_plus__Sample_Purchase_Mean = []
for i in range(1,1000):
    Age_0_17__Sample_Purchase_Mean.append(df.loc[df['Age']=='0-17','Purchase'].sample(sample_size).mean())
    Age_18_25__Sample_Purchase_Mean.append(df.loc[df['Age']=='18-25','Purchase'].sample(sample_size).mean())
    Age_26_35__Sample_Purchase_Mean.append(df.loc[df['Age']=='26-35','Purchase'].sample(sample_size).mean())
    Age_36_45__Sample_Purchase_Mean.append(df.loc[df['Age']=='36-45','Purchase'].sample(sample_size).mean())
    Age_46_50__Sample_Purchase_Mean.append(df.loc[df['Age']=='46-50','Purchase'].sample(sample_size).mean())
    Age_51_55__Sample_Purchase_Mean.append(df.loc[df['Age']=='51-55','Purchase'].sample(sample_size).mean())
    Age_55_plus__Sample_Purchase_Mean.append(df.loc[df['Age']=='55+','Purchase'].sample(sample_size).mean())
    
# Plotting histogram for both Married & Un-Married for Purchases
plt.figure(figsize=(20,5))
plt.subplot(1,7,1)
sns.histplot(Age_0_17__Sample_Purchase_Mean,kde=True)
plt.title("Age 0-17 vs Purchase")

plt.subplot(1,7,2)
sns.histplot(Age_18_25__Sample_Purchase_Mean,kde=True)
plt.title("Age 18-25 vs Purchase")

plt.subplot(1,7,3)
sns.histplot(Age_26_35__Sample_Purchase_Mean,kde=True)
plt.title("Age 26-35 vs Purchase")

plt.subplot(1,7,4)
sns.histplot(Age_36_45__Sample_Purchase_Mean,kde=True)
plt.title("Age 36-45 vs Purchase")

plt.subplot(1,7,5)
sns.histplot(Age_46_50__Sample_Purchase_Mean,kde=True)
plt.title("Age 46-50 vs Purchase")

plt.subplot(1,7,6)
sns.histplot(Age_51_55__Sample_Purchase_Mean,kde=True)
plt.title("Age 51-55 vs Purchase")

plt.subplot(1,7,7)
sns.histplot(Age_55_plus__Sample_Purchase_Mean,kde=True)
plt.title("Age 55 + vs Purchase")
plt.show()

############################ for sample(n=3000) & 90% confidence calculation of CI ######################################
# Age Group 0-17 mean Calculation & Standar deviation Calculation for Sample
Age_0_17_sample_3000_sd = Age_0_17_Population_std/math.sqrt(sample_size)
print("Standard Deviation for Age group 0-17 samples :",Age_0_17_sample_3000_sd)
# Age Group 18-25 mean Calculation & Standar deviation Calculation for Sample
Age_18_25_sample_3000_sd = Age_18_25_Population_std/math.sqrt(sample_size)
print("Standard Deviation for Age group 18-25 samples :",Age_18_25_sample_3000_sd)
# Age Group_26-35 mean Calculation & Standar deviation Calculation for Sample
Age_26_35_sample_3000_sd = Age_26_35_Population_std/math.sqrt(sample_size)
print("Standard Deviation for Age group 26-35 samples :",Age_26_35_sample_3000_sd)
# Age Group 36-45 mean Calculation & Standar deviation Calculation for Sample
Age_36_45_sample_3000_sd = Age_36_45_Population_std/math.sqrt(sample_size)
print("Standard Deviation for Age group 36-45 samples :",Age_36_45_sample_3000_sd)
# Age Group 46-50 mean Calculation & Standar deviation Calculation for Sample
Age_46_50_sample_3000_sd = Age_46_50_Population_std/math.sqrt(sample_size)
print("Standard Deviation for Age group 46-50 samples :",Age_46_50_sample_3000_sd)
# Age Group 51-55 mean Calculation & Standar deviation Calculation for Sample
Age_51_55_sample_3000_sd = Age_51_55_Population_std/math.sqrt(sample_size)
print("Standard Deviation for Age group 51-55 samples :",Age_51_55_sample_3000_sd)
# Age Group 55_plus mean Calculation & Standar deviation Calculation for Sample
Age_55_plus_sample_3000_sd = Age_55_plus_Population_std/math.sqrt(sample_size)
print("Standard Deviation for Age group 55_plus samples :",Age_55_plus_sample_3000_sd)

############# Calculation of Z-Score & confidence Interval (CI = [mu - Z*(s.d/root(n)), mu - Z*(s.d/root(n))]) ##############
alpha = 10/100
Z_3000 = abs(norm.ppf(alpha))

# Range Calculation for Age group of 0-17 people
print("CI range for Age group of 0-17 people at 90% confidence is [{}, {}]"
      .format(Age_0_17_Population_Mean  - Z_3000 *Age_0_17_sample_3000_sd,
              Age_0_17_Population_Mean  + Z_3000 *Age_0_17_sample_3000_sd))
# Range Calculation for Age group of 18-25 people
print("CI range for Age group of 18-25 people at 90% confidence is [{}, {}]"
      .format(Age_18_25_Population_Mean  - Z_3000 *Age_18_25_sample_3000_sd,
              Age_18_25_Population_Mean  + Z_3000 *Age_18_25_sample_3000_sd))
# Range Calculation for Age group of 26-35 people
print("CI range for Age group of 26-35 people at 90% confidence is [{}, {}]"
      .format(Age_26_35_Population_Mean  - Z_3000 *Age_26_35_sample_3000_sd,
              Age_26_35_Population_Mean  + Z_3000 *Age_26_35_sample_3000_sd))
# Range Calculation for Age group of 36-45 people
print("CI range for Age group of 36-45 people at 90% confidence is [{}, {}]"
      .format(Age_36_45_Population_Mean  - Z_3000 *Age_36_45_sample_3000_sd,
              Age_36_45_Population_Mean  + Z_3000 *Age_36_45_sample_3000_sd))
# Range Calculation for Age group of 46-50 people
print("CI range for Age group of 46-50 people at 90% confidence is [{}, {}]"
      .format(Age_46_50_Population_Mean  - Z_3000 *Age_46_50_sample_3000_sd,
              Age_46_50_Population_Mean  + Z_3000 *Age_46_50_sample_3000_sd))
# Range Calculation for Age group of 51-55 people
print("CI range for Age group of 51-55 people at 90% confidence is [{}, {}]"
      .format(Age_51_55_Population_Mean  - Z_3000 *Age_51_55_sample_3000_sd,
              Age_51_55_Population_Mean  + Z_3000 *Age_51_55_sample_3000_sd))
# Range Calculation for Age group of 55_plus people
print("CI range for Age group of 55_plus people at 90% confidence is [{}, {}]"
      .format(Age_55_plus_Population_Mean  - Z_3000 *Age_55_plus_sample_3000_sd,
              Age_55_plus_Population_Mean  + Z_3000 *Age_55_plus_sample_3000_sd))






print()
print("_ "*60)

#############################################################################################################################
# Out:
# For Sample size of 300 & 99% Confidence i.e. (alpha = 1%)
# Standard Deviation for Age group 0-17 samples : 295.0903070318576
# Standard Deviation for Age group 18-25 samples : 290.6567160257153
# Standard Deviation for Age group 26-35 samples : 289.2829287170726
# Standard Deviation for Age group 36-45 samples : 289.99864537778103
# Standard Deviation for Age group 46-50 samples : 286.78237066930916
# Standard Deviation for Age group 51-55 samples : 293.7193330225002
# Standard Deviation for Age group 55_plus samples : 289.3387407403851
# CI range for Age group of 0-17 people at 99% confidence is [8246.981932031353, 9619.947348858595]
# CI range for Age group of 18-25 people at 99% confidence is [8493.494972859175, 9845.832239663403]
# CI range for Age group of 26-35 people at 99% confidence is [8579.717906652619, 9925.663359087157]
# CI range for Age group of 36-45 people at 99% confidence is [8656.71296276855, 10005.988427067197]
# ...

# %% [markdown]
# # <font color=red>6.Business Insights based on Non- Graphical and Visual Analysis </font>

# %% [markdown]
# #### 6.1. Non-Graphical

# %% [markdown]
# > - No of Male Purchasing is more compared to female.
# (**M** :   414259,
# **F** :   135809)
# > - City Category having more count are ordered as **B > C > A**
# (**B** : 231173, **C** : 171175, **A** : 147720)
# > - No of people **married(225337)** are lesser than **UnMarried(324731)**
# > - People purchasing Age wise are in Descending order with no of counts as follows:
# (**26-35:** 219587,
# **36-45:** 110013,
# **18-25:** 99660,
# **46-50:** 45701,
# **51-55:** 38501,
# **55+  :** 21504,
# **0-17 :** 5102)
# > - Total no of unique Customer i.e. (Unique_ID) is : **5891**

# %% [markdown]
# #### 6.2 Graphical

# %% [markdown]
# > - Number of years stay in current city 1 is having highest no of count of orders
# > - Male & Female had a Total purchase of  **Product Category 1** as highest.

# %% [markdown]
# # <font color=red>7.Final Insights from Confidence Interval & CLT </font>

# %% [markdown]
# ### Observation from Central limit & Confidece Interval for Purchase vs Gender
# > - **The population Mean is mu:9437.526040472265 & population Standard Deviation is sd:5092.18620977797 when gender is Male**
# > - **The population Mean is mu:8734.565765155476 & population Standard Deviation is sd:4767.233289291458 when gender is Female**
#
# **For sample size of 300**
# - CI range for Male at 99% confidence is [8753.585563000677, 10121.466517943853] & S.D is 293.99750789790113,
# - CI range for Female at 99% confidence is [8094.2702854191575, 9374.861244891794] & S.D is 275.2363422862168
# ------------------------------------------------------------------------------------------------------------------------
# - CI range for Male at 95% confidence is [8953.943173291707, 9921.108907652822] & S.D is 293.99750789790113
# - CI range for Female at 95% confidence is [8281.842269277135, 9187.289261033817] & S.D is 275.2363422862168
# ------------------------------------------------------------------------------------------------------------------------
# - CI range for Male at 90% confidence  is [9060.753073959499, 9814.299006985031] & S.D is 293.99750789790113,
# - CI range for Female at 90% confidence  is [8381.836199803805, 9087.295330507146] & S.D is 275.2363422862168
# ------------------------------------------------------------------------------------------------------------------------
# **For Sample Size of 3000**
# - CI range for Male at 99% confidence is [9221.245071192936, 9653.807009751594] & S.D is 92.97017513707094
# - CI range for Female at 99% confidence is [8532.08655600778, 8937.044974303171] & S.D is 87.0373736478161
# ------------------------------------------------------------------------------------------------------------------------
# - CI range for Male at 95% confidence  is [9284.60371069974, 9590.44837024479] & S.D is 92.97017513707094
# - CI range for Female at 95% confidence  is [8591.402025430534, 8877.729504880417] & S.D is 87.0373736478161
# ------------------------------------------------------------------------------------------------------------------------
# - CI range for Male at 90% confidence is [9318.379966976396, 9556.672113968134] & S.D is 92.97017513707094
# - CI range for Female at 90% confidence  is [8623.022882696227, 8846.108647614725] & S.D is 87.0373736478161
# ------------------------------------------------------------------------------------------------------------------------
#
# **For Sample Size of 30000**
# - CI range for Male at 99% confidence is [9369.131992725106, 9505.920088219424] & S.D is 29.399750789790115
# - CI range for Female at 99% confidence is [8670.536217181843, 8798.595313129108] & S.D is 27.523634228621685
# ------------------------------------------------------------------------------------------------------------------------
# - CI range for Male at 95% confidence  is [9389.16775375421, 9485.88432719032] & S.D is 29.399750789790115
# - CI range for Female at 95% confidence  is [8689.293415567641, 8779.83811474331] & S.D is 27.523634228621685
# ------------------------------------------------------------------------------------------------------------------------
# - CI range for Male at 90% confidence is [9399.848743820989, 9475.203337123541] & S.D is 29.399750789790115
# - CI range for Female at 90% confidence is [8699.292808620308, 8769.838721690643] & S.D is 27.523634228621685
#
# > - We can say from above Data that as the **Sample size increase give (alpha=constant)** the **Confidence Interval range come closer** irrespective of Gender.
# > - We can also conclude that as the **alpha increase given (sample size = Constant)** the **Confidence interval Range come closer** irrespective of Gender.
# > - As the Sample size **increase** The Standard Deviation **Decreases**
#
# > **Purchase Confidence interval range for Males are always Higher than Female for all the sample size & alpha. So we can conclude from this Male Purchase more than female i.e Expense of Male is more than that of Female.**

# %% [markdown]
# ### Observation from Central limit & Confidece Interval for Purchase vs Marital_Status
# > - **The population Mean is mu:9265.907618921507 & population Standard Deviation is sd: 5027.347858674449 when MaritalStatus is 'Married'**
# > - **The population Mean is mu:9261.174574082374  & population Standard Deviation is sd:5016.897377793055 when MaritalStatus is 'Un-Married'**
#
# **For Sample size of 300**
# - CI range for Married at 99% confidence is [8590.675694316085, 9941.139543526928] & S.D is 290.2540639515581,
# - CI range for Un-Married at 99% confidence is [8587.346271926992, 9935.002876237755] & S.D is 289.65070515655475
# ------------------------------------------------------------------------------------------------------------------------
# - CI range for Married at 95% confidence is [8788.482169093382, 9743.333068749631] & S.D is 290.2540639515581
# - CI range for Un-Married at 95% confidence is [8784.741561156563, 9737.607587008184] & S.D is 289.65070515655475
# ------------------------------------------------------------------------------------------------------------------------
# - CI range for Married at 90% confidence  is [8893.932068858705, 9637.883168984308] & S.D is 290.2540639515581,
# - CI range for Un-Married at 90% confidence  is [8889.972259427894, 9632.376888736853] & S.D is 289.65070515655475
# ------------------------------------------------------------------------------------------------------------------------
# **For Sample size of 3000**
# - CI range for Married at 99% confidence is [9052.380535860284, 9479.43470198273] & S.D is 91.78639422070964
# - CI range for Un-Married at 99% confidence is [9048.091355412858, 9474.257792751889] & S.D is 91.59559541685911
# ------------------------------------------------------------------------------------------------------------------------
# - CI range for Married at 95% confidence is [9114.932435482775, 9416.882802360238] & S.D is 91.78639422070964
# - CI range for Un-Married at 95% confidence is [9110.513226748173, 9411.835921416574] & S.D is 91.59559541685911
# ------------------------------------------------------------------------------------------------------------------------
# - CI range for Married at 90% confidence  is [9148.278621712263, 9383.53661613075] & S.D is 91.78639422070964
# - CI range for Un-Married at 90% confidence  is [9143.790095378909, 9378.559052785839] & S.D is 91.59559541685911
# ------------------------------------------------------------------------------------------------------------------------
# **For Sample size of 30000**
# - CI range for Married at 99% confidence is [9198.384426460965, 9333.430811382048] & S.D is 29.025406395155816
# - CI range for Un-Married at 99% confidence is [9193.791743866836, 9328.557404297911] & S.D is 28.96507051565548
# ------------------------------------------------------------------------------------------------------------------------
# - CI range for Married at 95% confidence is [9218.165073938693, 9313.65016390432] & S.D is 29.025406395155816
# - CI range for Un-Married at 95% confidence is [9213.531272789793, 9308.817875374954] & S.D is 28.96507051565548
# ------------------------------------------------------------------------------------------------------------------------
# - CI range for Married at 90% confidence  is [9228.710063915227, 9303.105173927786] & S.D is 29.025406395155816
# - CI range for Un-Married at 90% confidence  is [9224.054342616926, 9298.294805547821] & S.D is 28.96507051565548
# ------------------------------------------------------------------------------------------------------------------------
# > - We can say from above Data that as the **Sample size increase give (alpha=constant)** the **Confidence Interval range come closer** irrespective of Marital Status.
# > - We can also conclude that as the **alpha increase given (sample size = Constant)** the **Confidence interval Range come closer** irrespective of Marital Status.
# > - As the Sample size **increase** The Standard Deviation **Decreases**
#
# > - **Purchase Confidence interval range for Married & Un-Married are overlapping for all the sample size & alpha. So we cannot conclude about Purchase Status for Married/un-Married which is greater**
# > - **But, we can say that Married Confidence Interval range is wider than Un_Married for all Sample size  & range come closer for different alpha**

# %% [markdown]
# ### Observation from Central limit & Confidece Interval for Purchase vs Age Group
#
# > - **The population Mean is mu:8933.464640444974  & population Standard Deviation is sd: 5111.11404600277 when Age group is '0 - 17'**
# > - **The population Mean is mu:9169.663606261289  & population Standard Deviation is sd:5034.32199717658 when Age group is '18 - 25'**
# > - **The population Mean is mu:9252.690632869888  & population Standard Deviation is sd: 5010.527303002956 when Age group is '26 - 35'**
# > - **The population Mean is mu:9331.350694917874  & population Standard Deviation is sd:5022.923879204662 when Age group is '36 - 45'**
# > - **The population Mean is mu:9208.625697468327 & population Standard Deviation is sd: 4967.216367142941 when Age group is '46 - 50'**
# > - **The population Mean is mu:9534.808030960236  & population Standard Deviation is sd:5087.368079602135 when Age group is '51 - 55'**
# > - **The population Mean is mu:9336.280459449405  & population Standard Deviation is sd: 5011.4939956034605 when Age group is '50 + '**
#
# **For Sample size of 300**
# - CI range for Age Group '0-17' at 99% confidence is [8246.981932031353, 9619.947348858595] & S.D is 295.0903070318576
# - CI range for Age Group '18-25' at 99% confidence is [8493.494972859175, 9845.832239663403] & S.D is 290.6567160257153
# - CI range for Age Group '26-35' at 99% confidence is [8579.717906652619, 9925.663359087157] & S.D is 289.2829287170726
# - CI range for Age Group '36-45' at 99% confidence is [8656.71296276855, 10005.988427067197] & S.D is 289.99864537778103
# - CI range for Age Group '46-50' at 99% confidence is [8541.470139149387, 9875.781255787268] & S.D is 286.78237066930916
# - CI range for Age Group '51-55' at 99% confidence is [8851.514685018648, 10218.101376901823] & S.D is 293.7193330225002
# - CI range for Age Group '55 + ' at 99% confidence is [8663.177895050356, 10009.383023848453] & S.D is 289.3387407403851
# ------------------------------------------------------------------------------------------------------------------------
# - CI range for Age Group '0-17' at 95% confidence is [8448.0842786454, 9418.845002244549] & S.D is 295.0903070318576
# - CI range for Age Group '18-25' at 95% confidence is [8691.575852708587, 9647.75135981399] & S.D is 290.6567160257153
# - CI range for Age Group '26-35' at 95% confidence is [8776.862558354467, 9728.518707385309] & S.D is 289.2829287170726
# - CI range for Age Group '36-45' at 95% confidence is [8854.345371257217, 9808.35601857853] & S.D is 289.99864537778103
# - CI range for Age Group '46-50' at 95% confidence is [8736.910674927172, 9680.340720009483] & S.D is 286.78237066930916
# - CI range for Age Group '51-55' at 95% confidence is [9051.682720732408, 10017.933341188063] & S.D is 293.7193330225002
# - CI range for Age Group '55 + ' at 95% confidence is [8860.360582325011, 9812.200336573798] & S.D is 289.3387407403851
# ------------------------------------------------------------------------------------------------------------------------
# - CI range for Age Group '0-17' at 90% confidence is [8555.29119549126, 9311.638085398688] & S.D is 295.0903070318576
# - CI range for Age Group '18-25' at 90% confidence is [8797.172036802482, 9542.155175720096] & S.D is 290.6567160257153
# - CI range for Age Group '26-35' at 90% confidence is [8881.959642687196, 9623.42162305258] & S.D is 289.2829287170726
# - CI range for Age Group '36-45' at 90% confidence is [8959.702476928165, 9702.998912907582] & S.D is 289.99864537778103
# - CI range for Age Group '46-50' at 90% confidence is [8841.099301366483, 9576.152093570172] & S.D is 286.78237066930916
# - CI range for Age Group '51-55' at 90% confidence is [9158.391559894535, 9911.224502025936] & S.D is 293.7193330225002
# - CI range for Age Group '55 + ' at 90% confidence is [8965.477943280861, 9707.082975617948] & S.D is 289.3387407403851
# ------------------------------------------------------------------------------------------------------------------------
# **For Sample size of 3000**
# - CI range for Age Group '0-17' at 99% confidence is [8716.379747154146, 9150.549533735802] & S.D is 93.31574856590714
# - CI range for Age Group '18-25' at 99% confidence is [8955.84030986988, 9383.486902652698] & S.D is 91.9137239866024
# - CI range for Age Group '26-35' at 99% confidence is [9039.87797106794, 9465.503294671837] & S.D is 91.47929429500805
# - CI range for Age Group '36-45' at 99% confidence is [9118.011512009627, 9544.68987782612] & S.D is 91.7056237757249
# - CI range for Age Group '46-50' at 99% confidence is [8997.652585675412, 9419.598809261242] & S.D is 90.68854840976839
# - CI range for Age Group '51-55' at 99% confidence is [9318.731702638957, 9750.884359281514] & S.D is 92.8822085176609
# - CI range for Age Group '55 + ' at 99% confidence is [9123.426739209288, 9549.134179689521] & S.D is 91.49694360645704
# ------------------------------------------------------------------------------------------------------------------------
# - CI range for Age Group '0-17' at 95% confidence is [8779.97389296465, 9086.955387925298] & S.D is 93.31574856590714
# - CI range for Age Group '18-25' at 95% confidence is [9018.47898399531, 9320.848228527268] & S.D is 91.9137239866024
# - CI range for Age Group '26-35' at 95% confidence is [9102.220583857783, 9403.160681881993] & S.D is 91.47929429500805
# - CI range for Age Group '36-45' at 95% confidence is [9180.508367038525, 9482.193022797223] & S.D is 91.7056237757249
# - CI range for Age Group '46-50' at 95% confidence is [9059.456309693556, 9357.795085243099] & S.D is 90.68854840976839
# - CI range for Age Group '51-55' at 95% confidence is [9382.030393400699, 9687.585668519772] & S.D is 92.8822085176609
# - CI range for Age Group '55 + ' at 95% confidence is [9185.78137990335, 9486.779538995459] & S.D is 91.49694360645704
# ------------------------------------------------------------------------------------------------------------------------
# - CI range for Age Group '0-17' at 90% confidence is [8813.87569678037, 9053.053584109579] & S.D is 93.31574856590714
# - CI range for Age Group '18-25' at 90% confidence is [9051.871429391224, 9287.455783131354] & S.D is 91.9137239866024
# - CI range for Age Group '26-35' at 90% confidence is [9135.455200051205, 9369.92606568857] & S.D is 91.47929429500805
# - CI range for Age Group '36-45' at 90% confidence is [9213.825209198849, 9448.876180636898] & S.D is 91.7056237757249
# - CI range for Age Group '46-50' at 90% confidence is [9092.403646276822, 9324.847748659833] & S.D is 90.68854840976839
# - CI range for Age Group '51-55' at 90% confidence is [9415.774691223187, 9653.841370697284] & S.D is 92.8822085176609
# - CI range for Age Group '55 + ' at 90% confidence is [9219.022408128003, 9453.538510770806] & S.D is 91.49694360645704
# ------------------------------------------------------------------------------------------------------------------------
# > - We can say from above Data that as the **Sample size increase give (alpha=constant)** the **Confidence Interval range come closer** irrespective of Age Group.
# > - We can also conclude that as the **alpha increase given (sample size = Constant)** the **Confidence interval Range come closer** irrespective of Age Group.
# > - As the Sample size **increase** The Standard Deviation **Decreases**
#
# > - **Purchase Confidence interval range for Age Group 0-17 is Highest as compared to other Age group & 46-50 confidence interval age group purchase is Lowest as compared to other Age group**
# > - **Even though Age Group 26-35 has the highest No of Orders its Confidence Interval range is Second lowest for Purchase**

# %% [markdown]
# # <font color=red>8. Recommendations </font>

# %% [markdown]
# > - Males are having highest no of orders & also Purchase confidence interval Compared to Females. So we can attract Females by discounting on certain Products or Advertise more
# ------------------------------------------------------------------------------------------------------------------------
# > - Married people Confidence interval is wider So it's better to provide "Package or Combo Sales offer" for them and for Unmarried we can increase Sales by providing Complimentary.
# ------------------------------------------------------------------------------------------------------------------------
# > - Age group 26-35 has highest no of orders but their Purchase amount is second lowes as compared to other Age Group. This is a age group of adulting age so we can provide offer to them as they are mor likely to purchase & also this is an important Age group as they are more Frequent Buyers
# ------------------------------------------------------------------------------------------------------------------------
# > - Age Group 0-17 has a wider Confidence interval range So this age group purchase a product which consist of variety of product from Cheaper Category to Premimu category. This Age group has an higher potential to increase Sale of a Company as they are more active in buying & always eager to buy
# ------------------------------------------------------------------------------------------------------------------------
# > - Age group 45-50 are having least Confidence interval Range bcoz they are not also a Frequent Buyer they Purchase very Rare so we Can use this Age group for Quality over Quantity as these are Smart buyers
